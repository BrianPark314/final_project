# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
# %cd data
# Out:
# c:\Users\User\document\final_project\data

# %%
# 처방전 관련 데이터(2021년 3월 1000만개정도 처방받은 데이터)
df = pd.read_csv('data1.csv',encoding='cp949')
df = df[['가입자 일련번호', '처방내역일련번호', '일련번호', '성별코드', '연령대코드(5세단위)', '시도코드','약품일반성분명코드', '총투여일수', '단가', '금액']]

province_codes = {11: '서울특별시',26: '부산광역시',27: '대구광역시',28: '인천광역시',29: '광주광역시',30: '대전광역시',31: '울산광역시',36: '세종특별자치시',
    41: '경기도',42: '강원도',43: '충청북도',44: '충청남도',45: '전라북도',46: '전라남도',47: '경상북도',48: '경상남도',49: '제주특별자치도'}

df['시도명'] = df['시도코드'].map(province_codes)
df['시도명']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # 처방전 관련 데이터(2021년 3월 1000만개정도 처방받은 데이터)
# ----> 2 df = pd.read_csv('data1.csv',encoding='cp949')
#       3 df = df[['가입자 일련번호', '처방내역일련번호', '일련번호', '성별코드', '연령대코드(5세단위)', '시도코드','약품일반성분명코드', '총투여일수', '단가', '금액']]
#       5 province_codes = {11: '서울특별시',26: '부산광역시',27: '대구광역시',28: '인천광역시',29: '광주광역시',30: '대전광역시',31: '울산광역시',36: '세종특별자치시',
#       6     41: '경기도',42: '강원도',43: '충청북도',44: '충청남도',45: '전라북도',46: '전라남도',47: '경상북도',48: '경상남도',49: '제주특별자치도'}
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\pandas\io\parsers\readers.py:583, in _read(filepath_or_buffer, kwds)
#     580     return parser
#     582 with parser:
# --> 583     return parser.read(nrows)
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\pandas\io\parsers\readers.py:1721, in TextFileReader.read(self, nrows)
#    1718     else:
#    1719         new_rows = len(index)
# -> 1721     df = DataFrame(col_dict, columns=columns, index=index)
#    1723     self._currow += new_rows
#    1724 return df
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\pandas\core\internals\construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\pandas\core\internals\construction.py:153, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     150 axes = [columns, index]
#     152 if typ == "block":
# --> 153     return create_block_manager_from_column_arrays(
#     154         arrays, axes, consolidate=consolidate, refs=refs
#     155     )
#     156 elif typ == "array":
#     157     return ArrayManager(arrays, [index, columns])
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\pandas\core\internals\managers.py:2142, in create_block_manager_from_column_arrays(arrays, axes, consolidate, refs)
#    2140     raise_construction_error(len(arrays), arrays[0].shape, axes, e)
#    2141 if consolidate:
# -> 2142     mgr._consolidate_inplace()
#    2143 return mgr
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\pandas\core\internals\managers.py:1829, in BlockManager._consolidate_inplace(self)
#    1823 def _consolidate_inplace(self) -> None:
#    1824     # In general, _consolidate_inplace should only be called via
#    1825     #  DataFrame._consolidate_inplace, otherwise we will fail to invalidate
#    1826     #  the DataFrame's _item_cache. The exception is for newly-created
#    1827     #  BlockManager objects not yet attached to a DataFrame.
#    1828     if not self.is_consolidated():
# -> 1829         self.blocks = _consolidate(self.blocks)
#    1830         self._is_consolidated = True
#    1831         self._known_consolidated = True
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\pandas\core\internals\managers.py:2272, in _consolidate(blocks)
#    2270 new_blocks: list[Block] = []
#    2271 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2272     merged_blocks, _ = _merge_blocks(
#    2273         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2274     )
#    2275     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2276 return tuple(new_blocks)
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\pandas\core\internals\managers.py:2297, in _merge_blocks(blocks, dtype, can_consolidate)
#    2290 new_values: ArrayLike
#    2292 if isinstance(blocks[0].dtype, np.dtype):
#    2293     # error: List comprehension has incompatible type List[Union[ndarray,
#    2294     # ExtensionArray]]; expected List[Union[complex, generic,
#    2295     # Sequence[Union[int, float, complex, str, bytes, generic]],
#    2296     # Sequence[Sequence[Any]], SupportsArray]]
# -> 2297     new_values = np.vstack([b.values for b in blocks])  # type: ignore[misc]
#    2298 else:
#    2299     bvals = [blk.values for blk in blocks]
#
# File <__array_function__ internals>:180, in vstack(*args, **kwargs)
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\numpy\core\shape_base.py:282, in vstack(tup)
#     280 if not isinstance(arrs, list):
#     281     arrs = [arrs]
# --> 282 return _nx.concatenate(arrs, 0)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
df.head()
# Out:
#    가입자 일련번호  처방내역일련번호  일련번호  성별코드  연령대코드(5세단위)  시도코드  약품일반성분명코드  총투여일수     단가
# 0    666668   5260626     2     1           11    43  134103ATB      4  476.0  \
# 1    666668   6859861     1     1           11    43  146432ASS      3   14.0
# 2    666668    769595     1     1           11    43  451302ATB      7   53.0
# 3    666668   6859861     4     1           11    43  185102ACH      3   30.0
# 4    666668   9307313     2     1           11    43  260100ACR      3  302.0
#
#      금액   시도명
# 0  7616  충청북도
# 1  1680  충청북도
# 2   186  충청북도
# 3    90  충청북도
# 4   906  충청북도

# %%
# 약품별 분류번호등 정보 
df2 = pd.read_csv('data2.csv',encoding='cp949')

# %%
df2.head()
# Out:
#        일반명코드 제형구분코드       제형                               일반명  분류번호   투여
# 0  100101AGN     GN  과립제,세립                            상황균사체엑스   421  내복   \
# 1  100101ALQ     LQ      액제                            상황균사체엑스   421  내복
# 2  100101APD     PD      산제   phellinus linteus mycelliun ext.   421  내복
# 3  100102ACH     CH   경질캡슐제   phellinus linteus mycelliun ext.   421  내복
# 4  100102ALQ     LQ      액제   phellinus linteus mycelliun ext.   421  내복
#
#      함량          단위
# 0   1.1           g
# 1   1.1           g
# 2   1.1           g
# 3  0.55           g
# 4   1.1  g(55mg/mL)

# %%
# 진료 내역정보 (환자가 어떤 증상으로 약을 처방 받았는지)
df3 = pd.read_csv('data3.csv',encoding='cp949')

# %%
# 기호별 병 정보
df4 = pd.read_csv('data4.csv',encoding='cp949')
df4 = df4[['상병기호','한글명','영문영']]
df4.drop_duplicates(subset='상병기호', inplace=True) # 상병 중복제거
df4['상병기호']
# Out:
# 0         A00
# 1        A000
# 3        A001
# 5        A009
# 6         A01
#          ...
# 47791    Z992
# 47794    Z993
# 47795    Z994
# 47796    Z998
# 47797    Z999
# Name: 상병기호, Length: 21299, dtype: object

# %%
df_new = pd.merge(df, df2, left_on = '약품일반성분명코드', right_on ='일반명코드', how = 'left')  
df_new2 = pd.merge(df3, df4, left_on = '주상병코드', right_on ='상병기호', how = 'left') # (진료)기호별로 병이름을 알기위해 합침

# %%
df_new.isnull().sum()
df_new.dropna(inplace=True)

def age_level(age):
    if age == 1 or age == 2:
        result = '9세미만'
    elif age == 3 or age == 4:
        result = '10대'
    elif age == 5 or age == 6:
        result = '20대'
    elif age == 7 or age == 8:
        result = '30대'
    elif age == 9 or age == 10:
        result = '40대'
    elif age == 11 or age == 12:
        result = '50대'
    elif age == 13 or age == 14:
        result = '60대'
    elif age == 15 or age == 16:
        result = '70대'
    else:
        result = '80대'
    return result
        
df_new['연령대'] = df_new['연령대코드(5세단위)'].map(lambda x: age_level(x))
# df_new['연령대'].value_counts()

df_new = df_new[df_new['투여']=='내복 ']
df_new['분류번호'] = df_new['분류번호'].astype(int)
df_new.drop(['처방내역일련번호','일련번호','시도코드','약품일반성분명코드','제형구분코드','투여'],axis=1,inplace=True)
# df_new.groupby('일반명')['연령대'].value_counts() # 약품 종류가 6915개 / 연령대별로 어떻게 많이 먹는지 확인
df_new.head(3)
# Out:
#    가입자 일련번호  성별코드  연령대코드(5세단위)  총투여일수     단가    금액   시도명      일반명코드
# 0    666668     1           11      4  476.0  7616  충청북도  134103ATB  \
# 1    666668     1           11      3   14.0  1680  충청북도  146432ASS
# 2    666668     1           11      7   53.0   186  충청북도  451302ATB
#
#                     제형                                             일반명  분류번호
# 0              정제,저작정   ciprofloxacin hydrochloride (as ciprofloxacin)   629  \
# 1  현탁액제,현탁액용정제,현탁액용산제                            dioctahedral smectite   237
# 2              정제,저작정                                   chlorthalidone   213
#
#      함량           단위  연령대
# 0  0.25            g  50대
# 1    75  g(0.15g/mL)  50대
# 2    25           mg  50대

# %%
extracted_data= agelevel_name.apply(lambda x: x.head(3)) # 연령대별로 약별로 가장 많이 처방많이 받은약 3개씩 추출
extracted_data

# %%
df_new2 = df_new2[['가입자 일련번호','진료내역일련번호','성별코드','연령대코드','시도코드','진료과목코드','상병기호','한글명','영문영']]
df_new2.head(3)
# Out:
#    가입자 일련번호  진료내역일련번호  성별코드  연령대코드  시도코드  진료과목코드  상병기호                 한글명
# 0    666847   3243108     1     14    41       1  I109  기타 및 상세불명의 원발성 고혈압  \
# 1    666847   5512427     1     14    41       1  I109  기타 및 상세불명의 원발성 고혈압
# 2    666847   4023485     1     14    41       1  I109  기타 및 상세불명의 원발성 고혈압
#
#                                           영문영
# 0  Other and unspecified primary hypertension
# 1  Other and unspecified primary hypertension
# 2  Other and unspecified primary hypertension

# %%
data = pd.read_csv('df_merged.csv',encoding='utf-8')
data.head(3)
# Out:
#    idx                        file_name  width  height
# 0    0  K-019461_0_0_0_0_60_000_200.png    976    1280  \
# 1    1  K-019469_0_0_0_0_60_000_200.png    976    1280
# 2    2  K-019553_0_0_0_0_60_000_200.png    976    1280
#
#                            imgfile    drug_N drug_S back_color drug_dir
# 0  K-019461_0_0_0_0_60_000_200.png  K-019461   정상알약     검은색 배경       앞면  \
# 1  K-019469_0_0_0_0_60_000_200.png  K-019469   정상알약     검은색 배경       앞면
# 2  K-019553_0_0_0_0_60_000_200.png  K-019553   정상알약     검은색 배경       앞면
#
#   light_color  camera_la  camera_lo  size  dl_idx dl_mapping_code
# 0         전구색         60          0   200   19460        K-019461  \
# 1         전구색         60          0   200   19468        K-019469
# 2         전구색         60          0   200   19552        K-019553
#
#             dl_name              dl_name_en
# 0  미래트리메부틴정 100mg/병  Trimebutine Tab. Mirae  \
# 1     큐레틴정(빌베리건조엑스)             Qretin Tab.
# 2   콘택골드캡슐 10mg/PTP        Contac Gold Cap.
#
#                                              img_key
# 0  http://connectdi.com/design/img/drug/147427567...  \
# 1  http://connectdi.com/design/img/drug/147428234...
# 2  http://connectdi.com/design/img/drug/147427262...
#
#                        dl_material
# 0                        트리메부틴말레산염  \
# 1                          빌베리건조엑스
# 2  클로르페니라민말레산염|벨라돈나총알칼로이드|페닐레프린염산염
#
#                                       dl_material_en dl_custom_shape
# 0                                        Trimebutine         정제, 저작정  \
# 1                                Bilberry Dried Ext.         정제, 저작정
# 2  Phenylephrine Hydrochloride| Belladonna Total ...           경질캡슐제
#
#     item_seq  di_item_permit_date        di_class_no di_etc_otc_code
# 0  200607006             20060724  [02390]기타의 소화기관용약           일반의약품  \
# 1  200607018             20061009        [01310]안과용제           일반의약품
# 2  200607735             20060728      [01410]항히스타민제           일반의약품
#
#            di_edi_code drug_shape  thick  leng_long  leng_short print_front
# 0            657500470         원형   4.25       9.05        9.05         NaN  \
# 1  650101140,A28302561        타원형   5.65      12.84        7.60         QRT
# 2            642102330        장방형   6.77      19.08        6.42      YH CNT
#
#   print_back color_class1  img_regist_ts form_code_name  change_date    area
# 0       마크TM           연두     20110516.0             나정   20200930.0   50838  \
# 1        분할선           갈색     20070330.0          필름코팅정   20130129.0   72657
# 2        NaN           빨강     20071113.0     서방성캡슐제, 펠렛   20201116.0  126169
#
#    iscrowd                  bbox
# 0        0  [408, 519, 229, 222]
# 1        0  [350, 490, 299, 243]
# 2        0  [249, 406, 449, 281]

# %%
data.columns
# Out:
# Index(['idx', 'file_name', 'width', 'height', 'imgfile', 'drug_N', 'drug_S',
#        'back_color', 'drug_dir', 'light_color', 'camera_la', 'camera_lo',
#        'size', 'dl_idx', 'dl_mapping_code', 'dl_name', 'dl_name_en', 'img_key',
#        'dl_material', 'dl_material_en', 'dl_custom_shape', 'item_seq',
#        'di_item_permit_date', 'di_class_no', 'di_etc_otc_code', 'di_edi_code',
#        'drug_shape', 'thick', 'leng_long', 'leng_short', 'print_front',
#        'print_back', 'color_class1', 'img_regist_ts', 'form_code_name',
#        'change_date', 'area', 'iscrowd', 'bbox'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# idx                       0
# file_name                 0
# width                     0
# height                    0
# imgfile                   0
# drug_N                    0
# drug_S                    0
# back_color                0
# drug_dir                  0
# light_color               0
# camera_la                 0
# camera_lo                 0
# size                      0
# dl_idx                    0
# dl_mapping_code           0
# dl_name                   0
# dl_name_en               87
# img_key                  49
# dl_material              27
# dl_material_en          176
# dl_custom_shape         136
# item_seq                  0
# di_item_permit_date       0
# di_class_no               2
# di_etc_otc_code           0
# di_edi_code              99
# drug_shape               49
# thick                    22
# leng_long                21
# leng_short               23
# print_front              90
# print_back             2099
# color_class1             49
# img_regist_ts            49
# form_code_name           49
# change_date             244
# area                      0
# iscrowd                   0
# bbox                      0
# dtype: int64

# %%
data['image_id'].value_counts()
# Out:
# image_id
# 1    4024
# Name: count, dtype: int64

# %%
data = data[['file_name','drug_N','back_color','dl_idx','dl_name','dl_name_en','dl_material','dl_material_en',
              'dl_custom_shape','dl_company','dl_company_en','di_class_no','item_seq','di_etc_otc_code','di_edi_code','chart',
              'drug_shape','leng_long','leng_short','print_front','print_back','line_front','line_back','color_class1','form_code_name','area','bbox']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = data[['file_name','drug_N','back_color','dl_idx','dl_name','dl_name_en','dl_material','dl_material_en',
#       2               'dl_custom_shape','dl_company','dl_company_en','di_class_no','item_seq','di_etc_otc_code','di_edi_code','chart',
#       3               'drug_shape','leng_long','leng_short','print_front','print_back','line_front','line_back','color_class1','form_code_name','area','bbox']]
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\pandas\core\indexes\base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File c:\Users\User\document\final_project\.venv\lib\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['dl_company', 'dl_company_en', 'chart', 'line_front', 'line_back'] not in index"

# %%
data.to_csv('merge_data3.csv')

# %%
keys = ['file_name','drug_N','dl_idx','dl_name','dl_name_en','dl_material','dl_material_en','dl_company','dl_company_en','di_class_no','item_seq','di_etc_otc_code','di_edi_code','chart',
'drug_shape','print_front','print_back','color_class1','form_code_name']
values = ['파일이름','알약코드','알약 식별자','제품명','제품명(영어)','성분명','성분명(영어)','제조사명','제조사명(영어)','약품 분류','품목기준 코드','전문의약품 여부','EDI코드','제형',
'모양','식별문자(앞)','식별문자(뒤)','색상','정제 분류명','영역']
my_dict = dict(zip(keys, values))
data = data.rename(columns=my_dict)
data['분류코드'] = data['약품 분류'].str[2:5]

# %%
data.head(2)
# Out:
#                               파일이름      알약코드  알약 식별자               제품명
# 0  K-019461_0_0_0_0_60_000_200.png  K-019461   19460  미래트리메부틴정 100mg/병  \
# 1  K-019469_0_0_0_0_60_000_200.png  K-019469   19468     큐레틴정(빌베리건조엑스)
#
#                   제품명(영어)        성분명              성분명(영어)     제조사명
# 0  Trimebutine Tab. Mirae  트리메부틴말레산염          Trimebutine  미래제약(주)  \
# 1             Qretin Tab.    빌베리건조엑스  Bilberry Dried Ext.  (주)태준제약
#
#             제조사명(영어)              약품 분류    품목기준 코드 전문의약품 여부
# 0  Mirae Pharm Korea  [02390]기타의 소화기관용약  200607006    일반의약품  \
# 1      Taejoon Pharm        [01310]안과용제  200607018    일반의약품
#
#                  EDI코드              제형   모양 식별문자(앞) 식별문자(뒤)  색상 정제 분류명   area
# 0            657500470       연두색의 원형정제   원형     NaN    마크TM  연두     나정  50838  \
# 1  650101140,A28302561  적갈색의 타원형 필름코팅정  타원형     QRT     분할선  갈색  필름코팅정  72657
#
#   분류코드
# 0  239
# 1  131

# %%
data[data['분류코드']=='114']['성분명']
# Out:
# 6                                아세트아미노펜|이소프로필안티피린|카페인무수물
# 16                                         클로르족사존|아세트아미노펜
# 23                                              이부프로펜아르기닌
# 38                                                 덱시부프로펜
# 39                      금은화|연교|두시|우방자|박하|길경|감초|담죽엽|형개|영양각
#                               ...
# 3979    아세트아미노펜|구아이페네신|슈도에페드린염산염|클로페라스틴염산염|dl-메틸에페드린염산...
# 3980                                       아세트아미노펜|카페인수화물
# 3985                                              아세트아미노펜
# 3999                                       클로르족사존|아세트아미노펜
# 4022    아세트아미노펜|에텐자미드|티페피딘히벤즈산염|dl-메틸에페드린염산염|클로르페니라민말레...
# Name: 성분명, Length: 488, dtype: object

# %%
data[data['성분명(영어)'].str.contains('Triazolam')==True]['성분명(영어)']
# Out:
# Series([], Name: 성분명(영어), dtype: object)

# %%
multi_no = pd.read_excel('multino.xlsx')
multi_no = multi_no[['Unnamed: 1','Unnamed: 2','Unnamed: 3']]
multi_no = multi_no.rename(columns={'Unnamed: 1':'유효성분1','Unnamed: 2':'유효성분2', 'Unnamed: 3':'위험증상'})

# %%
multi_no.isnull().sum()
multi_no.dropna(subset='위험증상',inplace=True)
multi_no = multi_no[1:]
multi_no
# Out:
#                                                유효성분1
# 1                                         acemetacin  \
# 2                                         acemetacin
# 3                                      acetazolamide
# 4                                      acetazolamide
# 5                                          acitretin
# ...                                              ...
# 1152  Doravirine + Lamivudine + Tenofovir disoproxil
# 1153                                       Triazolam
# 1154                                       Triazolam
# 1155                                      Irinotecan
# 1156                                      Selegiline
#
#                          유효성분2
# 1                   diflunisal  \
# 2     methotrexate(분류번호 : 421)
# 3                methazolamide
# 4                   topiramate
# 5                  doxycycline
# ...                        ...
# 1152        Adefovir dipivoxil
# 1153                 Ritonavir
# 1154     Ritonavir + Lopinavir
# 1155           St. john's wort
# 1156                 Linezolid
#
#                                                    위험증상
# 1                                         중증의 위장관계 이상반응
# 2     신세뇨관에서 Methotrexate 배설이 지연되어 Methotrexate의 혈액학...
# 3                                         신장결석 형성 위험 증가
# 4                                                   신결석
# 5                                               두개내압 증가
# ...                                                 ...
# 1152  뉴클레오시드 유사체 단독투여 또는 다른 항레트로바이러스제를 병용투여했을 때 치명적인...
# 1153                              진정작용의 연장 또는 증가, 호흡 저하
# 1154                              진정작용의 연장 또는 증가, 호흡 저하
# 1155             이리노테칸 활성 대사물(SN-38)의 혈중 농도가 저하되어 작용 감소
# 1156  고혈압 위기의 위험 증가\n투여중지 후 MAO 억제제인 다른 약물을 투여하기까지 적...
#
# [1133 rows x 3 columns]

# %%
# 문제될수있는 성분을 포함하는 이미지를 추출해줌 
index_1 = data[data['성분명(영어)'].isin(multi_no['유효성분1'].values)]['성분명(영어)'].index # 문제될수 있는 성분1이 있는 index
index_2 = data[data['성분명(영어)'].isin(multi_no['유효성분2'].values)]['성분명(영어)'].index # 문제될수 있는 성분2이 있는 index 
# data['New Variable'] = data.index.isin(index_values).map(lambda x: True if x else False)

data['문제가능'] = None
data.loc[index_1,'문제가능'] = 'problem'
data.loc[index_2,'문제가능'] = 'problem'

# %%
data[data['문제가능']=='problem']['문제가능'] # 유효성분을 하나라도 포함하는 index만 추출
# Out:
# 31      problem
# 151     problem
# 177     problem
# 545     problem
# 615     problem
# 676     problem
# 688     problem
# 708     problem
# 710     problem
# 711     problem
# 712     problem
# 714     problem
# 716     problem
# 718     problem
# 776     problem
# 813     problem
# 827     problem
# 974     problem
# 1008    problem
# 1017    problem
# 1018    problem
# 1332    problem
# 1426    problem
# 1443    problem
# 1462    problem
# 1565    problem
# 1654    problem
# 1669    problem
# 1678    problem
# 1896    problem
# 2175    problem
# 2482    problem
# 2734    problem
# 2740    problem
# 2777    problem
# 3692    problem
# 3930    problem
# 3954    problem
# Name: 문제가능, dtype: object

# %%
data['성분명(영어)'].str.contains('Haloperidol').sum()
# Out:
# 5

# %%
multi_no[multi_no['유효성분1'].isin(data['성분명(영어)'])] # 문제되는 조합
# Out:
#             유효성분1         유효성분2                          위험증상
# 1082  Simvastatin  Cyclosporine  혈중농도 상승 및 근육병증/횡문근융해증 위험성 증가
# 1094  Haloperidol  Gemifloxacin                 QT간격 연장 위험 증가

# %%
multi_no[multi_no['유효성분2'].isin(data['성분명(영어)'])] # 문제되는 조합
# Out:
#                                                   유효성분1               유효성분2
# 1081                                       Atorvastatin        Cyclosporine  \
# 1082                                        Simvastatin        Cyclosporine
# 1083                                       Rosuvastatin        Cyclosporine
# 1084                                         Lovastatin        Cyclosporine
# 1085                                       Pitavastatin        Cyclosporine
# 1098                     Gimeracil + Oteracil + Tegafur        Capecitabine
# 1100                    Sulfamethoxazole + Trimethoprim        Methotrexate
# 1103                         Glecaprevir + Pibrentasvir         Simvastatin
# 1104                         Glecaprevir + Pibrentasvir       Carbamazepine
# 1105                         Glecaprevir + Pibrentasvir           Phenytoin
# 1108                                         Letermovir            Pimozide
# 1140                                     Zinc histidine     D-Penicillamine
# 1145  Bictegravir + Emtricitabine + Tenofovir alafen...  Adefovir dipivoxil
# 1146  Bictegravir + Emtricitabine + Tenofovir alafen...          Lamivudine
# 1151                                         Ranolazine        Itraconazole
# 1152     Doravirine + Lamivudine + Tenofovir disoproxil  Adefovir dipivoxil
#
#                                                    위험증상
# 1081                       혈중농도 상승 및 근육병증/횡문근융해증 위험성 증가
# 1082                       혈중농도 상승 및 근육병증/횡문근융해증 위험성 증가
# 1083                       혈중농도 상승 및 근육병증/횡문근융해증 위험성 증가
# 1084                       혈중농도 상승 및 근육병증/횡문근융해증 위험성 증가
# 1085                       혈중농도 상승 및 근육병증/횡문근융해증 위험성 증가
# 1098  해당 약물 병용 시 gimeracil에 의해 fluoropyrimidine 계열 약...
# 1100  신세뇨관에서 methotrexate 배설이 지연되어 methotrexate의 혈액학...
# 1103                         횡문근융해증을 비롯한 근육질환 등 중증 이상반응
# 1104  Glecaprevir와 Pibrentasvir의 혈장 농도가 유의하게 감소하여 이 ...
# 1105  Glecaprevir와 Pibrentasvir의 혈장 농도가 유의하게 감소하여 이 ...
# 1108  QT 연장, 심실성 빈맥, 심실세동 및 torsades de pointes 등 심독...
# 1140  아연 흡수를 저해하거나 배출을 증가시킴. 병용 시 최소 한 시간 이상 간격을 두고 투여함
# 1145                                양쪽 약물 모두 혈장농도 상승 가능
# 1146  라미부딘이 엠트리시타빈의 세포내 인산화를 저해할 수도 있음. 동일한 역전사효소 유전...
# 1151                                     라놀라진의 혈장 농도 증가
# 1152  뉴클레오시드 유사체 단독투여 또는 다른 항레트로바이러스제를 병용투여했을 때 치명적인...

# %%
data[data['성분명(영어)'] 'Haloperidol']
# Out:
# Empty DataFrame
# Columns: [파일이름, 알약코드, 알약 식별자, 제품명, 제품명(영어), 성분명, 성분명(영어), 제조사명, 제조사명(영어), 약품 분류, 품목기준 코드, 전문의약품 여부, EDI코드, 제형, 모양, 식별문자(앞), 식별문자(뒤), 색상, 정제 분류명, area, 분류코드, 유효1, 유효2, 문제가능]
# Index: []

# %%
no_list2 = multi_no[(data['성분명(영어)'].isin(multi_no['유효성분1'])) & (data['성분명(영어)'].isin(multi_no['유효성분2']))] 
no_list2 # 사진 성분이 유효성분을 포함하고 있을때
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12872\2948727367.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   no_list2 = multi_no[(data['성분명(영어)'].isin(multi_no['유효성분1'])) & (data['성분명(영어)'].isin(multi_no['유효성분2']))]
#         유효성분1           유효성분2         위험증상
# 31  amiloride  spironolactone  고칼륨혈증 위험 증가
