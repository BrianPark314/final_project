# %% [markdown]
# # Load dataset từ Kaggle

# %%
from google.colab import files
files.upload()

# %%
# !pip install kaggle

# %%
# !rm -r ~/.kaggle
# !mkdir ~/.kaggle
# !mv ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# rm: cannot remove '/root/.kaggle': No such file or directory

# %%
# !kaggle datasets download -d "npk7264/helmet-dataset"
# Out:
# ...
#  90% 67.0M/74.3M [00:00<00:00, 64.6MB/s]
# 100% 74.3M/74.3M [00:00<00:00, 83.7MB/s]

# %%
# !unzip /content/helmet-dataset.zip -d /content/helmet-dataset

# %% [markdown]
# # Train YOLO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Tryhard/Helmet Detection
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd /content/drive/MyDrive/Tryhard/Helmet Detection/yolov5
# !pip install -r requirements.txt

# %%
# train
# %cd /content/drive/MyDrive/Tryhard/Helmet_Detection/yolov5
# !python train.py --epochs 30 --weights yolov5s.pt --data data/custom_data.yaml

# %%
# %cd /content/drive/MyDrive/Tryhard/Helmet_Detection/yolov5
# !python detect.py --weights runs/train/exp/weights/best.pt --data data/custom_data.yaml --source /content/helmet-dataset/test/images/test25_jpg.rf.9948971b682377317e7987d31a1abedb.jpg
# Out:
# /content/drive/MyDrive/Tryhard/Helmet_Detection/yolov5
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/helmet-dataset/test/images/test25_jpg.rf.9948971b682377317e7987d31a1abedb.jpg, data=data/custom_data.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-134-g23c4923 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients
# image 1/1 /content/helmet-dataset/test/images/test25_jpg.rf.9948971b682377317e7987d31a1abedb.jpg: 640x640 1 helmet, 11.5ms
# Speed: 0.5ms pre-process, 11.5ms inference, 24.5ms NMS per image at shape (1, 3, 640, 640)
# ...
