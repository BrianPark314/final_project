# %% [markdown]
# # --------------------코랩에서만 돌아가는 코드!!!!!!!!!!!!--------------------------

# %% [markdown]
# ## 1. 구글 드라이브 마운트
#
# 구글 드라이브를 마운트해야 구글 드라이브에 yolo 코드를 다운받고, 드라이브에 있는 데이터로 학습을 할 수 있음

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive
# Out:
# /content/drive

# %%
# %pwd
# Out:
# '/content/drive'

# %%
# 작업 경로를 MyDrive로 변경하여 구글 드라이브에 접속 후 바로 작업 디렉토리를 확인 가능

print('현재 작업 경로 :', os.getcwd())
os.chdir('/content/drive/MyDrive')
print('변경된 작업 경로 :', os.getcwd())
# Out:
# 현재 작업 경로 : /content/drive
# 변경된 작업 경로 : /content/drive/MyDrive

# %% [markdown]
# ## 2. YOLOv5 레퍼지토리 다운로드
# 코드를 실행하면 구글 드라이브에 YOLO 코드가 다운로드
# 한 번만 다운로드하면 됨(구글 드라이브에 다운로드되니까)

# %%
# 처음에 한번만 실행 !
# !git clone https://github.com/ultralytics/yolov5  # YOLOv5 레퍼지토리 clone
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# 필요한 패키지 다운로드 및 임포트
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import yaml
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# /content/drive/MyDrive/yolov5
# Setup complete. Using torch 2.0.1+cu118 (Tesla T4)

# %% [markdown]
# ## 3. 데이터셋 다운로드, yaml 파일 수정 - 각자 진행
# - 사용하고자 하는 커스텀 데이터셋을 구글 드라이브에 'dataset'이라는 폴더에 업로드
# - 'dataset' 폴더 안에는 학습/평가 데이터와 어노테이션(라벨) 그리고 데이터셋에 대한 설명이 담긴 yaml파일 필요
#
# - Roboflow의 퍼블릭 데이터셋 사용
#   - [roboflow 퍼블릭 데이터셋](https://public.roboflow.com/object-detection)에서 사용하고 싶은 데이터셋 다운로드해서 해당 폴더에 업로드
#   - 여러 포맷으로 다운로드할 수 있는데 그 중에서 TXT - YOLOv5 PyTorch 로 다운로드
#
# - 그 외 커스텀 데이터셋 사용
#   - 다른 데이터셋이나 본인이 만든 데이터셋을 사용하고 싶다면 데이터, 라벨, yaml 파일을 모두 퍼블릭 데이터셋의 규격에 맞게 통일해줘야됨 (물론 코드 수정이 가능하다면 데이터셋 로딩하는 코드를 수정해도 됨)
#
# - yaml 파일 수정
#   - train, val(또는 test) 데이터가 있는 경로 수정 필요

# %%
# 사용할 데이터셋 경로 및 데이터셋의 yaml 파일 경로 지정
data_dir = '/content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/'
data_yaml = '/content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/data.yaml'

# %% [markdown]
# # ---------yaml파일안에 names 부분에 캡슐코드가 들어가야하고 아래 내가 넣은 이름들은 그냥 대충 넣어둔것,  nc가 의미하는것은 name갯수

# %%
# 데이터셋 yaml 파일 확인
with open(data_yaml) as f:
    film = yaml.load(f, Loader=yaml.FullLoader)
    display(film)
# Out:
# {'names': ['Epinare',
#   'tiafran',
#   'biometics capsule',
#   'bacilliformis capsule',
#   'Kratin20mg',
#   'Kratin10mg',
#   'Kratin5mg',
#   'Lacto NQ Capsule',
#   'Anagra capsules0.5mg',
#   'MuCo One Capsule',
#   'Ldomin Capsule300mg',
#   'biwoomi500mg',
#   'Endomin 300 Premium Soft Capsule 300mg',
#   'eldose in capsule',
#   'Ranofensemi',
#   'New Erdote Capsule',
#   'Refrega Capsules75mg',
#   'reselton capsule6.0mg',
#   'Bearrotan50mg',
#   'Beatus',
#   'Phytarotene2mg',
#   'Rukio10mg',
#   'ducarb5mg'],
#  'nc': 22,
#  'train': '/content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/testlabel',
#  'val': '/content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel'}

# %%
# %pwd
# Out:
# UsageError: CWD no longer exists - please use %cd to change directory.

# %%
# yaml 파일의 train, val 데이터가 있는 경로 수정 (기존 경로 -> 구글 드라이브에 저장된 경로로)
film['train'] = '/content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/testlabel'
film['val'] = '/content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel'

with open(data_yaml, 'w') as f:
    yaml.dump(film, f)

print('변경된 yaml 파일 :')
with open(data_yaml) as f:
    film = yaml.load(f, Loader=yaml.FullLoader)
    display(film)
# Out:
# 변경된 yaml 파일 :
# {'names': ['Epinare',
#   'tiafran',
#   'biometics capsule',
#   'bacilliformis capsule',
#   'Kratin20mg',
#   'Kratin10mg',
#   'Kratin5mg',
#   'Lacto NQ Capsule',
#   'Anagra capsules0.5mg',
#   'MuCo One Capsule',
#   'Ldomin Capsule300mg',
#   'biwoomi500mg',
#   'Endomin 300 Premium Soft Capsule 300mg',
#   'eldose in capsule',
#   'Ranofensemi',
#   'New Erdote Capsule',
#   'Refrega Capsules75mg',
#   'reselton capsule6.0mg',
#   'Bearrotan50mg',
#   'Beatus',
#   'Phytarotene2mg',
#   'Rukio10mg',
#   'ducarb5mg'],
#  'nc': 22,
#  'train': '/content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/testlabel',
#  'val': '/content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel'}

# %%
data_yaml
# Out:
# '/content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/data.yaml'

# %% [markdown]
# # 4. YOLOv5 모델 학습
# - 배치사이즈, 학습 에폭, 모델 사이즈 등을 선택하여 학습시킬 수 있음
# - 학습 결과 중 베스트 모델이 저장됨 -> 모델 저장된 경로 확인 필수!
#   - img: 입력 이미지 크기
#   - batch: 배치 사이즈
#   - epochs: 총 학습 에폭
#   - data: 데이터셋 yaml 파일 경로
#   - weights: 모델 웨이트 경로(pre-train된 모델로 학습시키기 때문에)
#   - cache: 캐시 이미지

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/
# Out:
# /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('./testlabel/K-038884_0_0_0_0_75_000_200.png')

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7F7ABFDFA4D0>

# %%
a = cv2.imread("")

# %%
# %cd ../../../../yolov5
# Out:
# /content/drive/MyDrive/yolov5

# %% [markdown]
# #여기서 아래 쓰여진 코드에 원래는 변수에 절대경로 넣어서 대입하는 방식이였는데 그게 안돌아가서 직접 코드에 절대경로 넣어서 돌린거기때문에 쓰는사람에따라서 경로 변경해서 진행시켜주면 됨.

# %%
# !python train.py --img 640 --batch 8 --epochs 50 --data '/content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/data.yaml' --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 2 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-185-g2334aa7 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=23
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     75516  models.yolo.Detect                      [23, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7081660 parameters, 7081660 gradients, 16.1 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/testlabel... 1859 images, 6 backgrounds, 0 corrupt: 100% 1865/1865 [00:38<00:00, 48.93it/s]
# train: New cache created: /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/testlabel.cache
# val: Scanning /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel.cache... 440 images, 0 backgrounds, 0 corrupt: 100% 440/440 [00:00<?, ?it/s]
#
# AutoAnchor: 4.37 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp14/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp14
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/49      1.86G    0.08199    0.02592    0.07959          2        640: 100% 234/234 [01:44<00:00,  2.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 28/28 [00:09<00:00,  3.05it/s]
#                    all        440        440   0.000522     0.0568   0.000634   0.000167
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/49      2.03G    0.06216    0.02339    0.07037         14        640:  74% 174/234 [01:16<00:26,  2.27it/s]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 633, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1328, in _next_data
#     idx, data = self._get_data()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1284, in _get_data
#     success, data = self._try_get_data()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1132, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/usr/lib/python3.10/queue.py", line 180, in get
#     self.not_empty.wait(remaining)
#   File "/usr/lib/python3.10/threading.py", line 324, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/yolov5/train.py", line 647, in <module>
#     main(opt)
#   File "/content/drive/MyDrive/yolov5/train.py", line 536, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "/content/drive/MyDrive/yolov5/train.py", line 291, in train
#     for i, (imgs, targets, paths, _) in pbar:  # batch -------------------------------------------------------------
#   File "/usr/local/lib/python3.10/dist-packages/tqdm/std.py", line 1178, in __iter__
#     for obj in iterable:
#   File "/content/drive/MyDrive/yolov5/utils/dataloaders.py", line 172, in __iter__
#     yield next(self.iterator)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 629, in __next__
#     with torch.autograd.profiler.record_function(self._profile_name):
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/profiler.py", line 507, in __exit__
#     torch.ops.profiler._record_function_exit._RecordFunction(record)
#   File "/usr/local/lib/python3.10/dist-packages/torch/_ops.py", line 286, in __call__
#     def __call__(self, *args, **kwargs):
# KeyboardInterrupt
# ^C

# %% [markdown]
# # 5. 텐서보드 시작하기
# 텐서보드는 학습시키는 딥러닝 모델이 잘 학습되는지 시각적으로 확인할 수 있는 어플리케이션이라보 보시면 좋을 것 같습니다.

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %% [markdown]
# # 6. 학습한 모델 테스트

# %%
# 테스트 이미지 경로
test_data_dir = film['val']

# 실험 번호 지정 - 진행한 실험이 저장된 경로 확인해서 기입! - runs/train/exp1 인지 exp2, exp3 인지 확인 후 아래 번호 지정
train_exp_num = 11

# %% [markdown]
# # 여기도 절대경로 넣어주면되고 img는 resize할 값을 설정 (클수록 성능은 좋으나 느림), conf값은 threadhold 값을 의미 0.5퍼 미만일땐 네모박스를 안그림. sorce값은 내가 학습시킨 best모델을 어떤 이미지를 넣어서 확인할지 하는 확인용 이미지가 들어가있는 폴더경로기입

# %%
# !python detect.py --weights '/content/drive/MyDrive/yolov5/runs/train/exp{train_exp_num}/weights/best.pt' --img 640 --conf 0.5 --source '/content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel'
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/exp11/weights/best.pt'], source=/content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-185-g2334aa7 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7072156 parameters, 0 gradients, 15.9 GFLOPs
# image 1/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038884_0_0_0_1_75_280_200.png: 640x512 1 Epinare, 45.4ms
# image 2/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038884_0_0_0_1_75_300_200.png: 640x512 1 Epinare, 1 Kratin5mg, 8.9ms
# image 3/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038884_0_0_0_1_75_320_200.png: 640x512 1 Epinare, 1 Kratin5mg, 8.9ms
# image 4/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038884_0_0_0_1_75_340_200.png: 640x512 1 Epinare, 1 Kratin5mg, 8.9ms
# image 5/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038884_0_0_0_1_90_000_200.png: 640x512 1 Epinare, 13.2ms
# image 6/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038884_0_0_0_1_90_020_200.png: 640x512 1 Epinare, 23.9ms
# image 7/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038884_0_0_0_1_90_040_200.png: 640x512 1 Epinare, 8.9ms
# image 8/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038884_0_0_0_1_90_060_200.png: 640x512 1 Epinare, 8.9ms
# image 9/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038884_0_0_0_1_90_080_200.png: 640x512 1 Epinare, 1 Kratin5mg, 8.9ms
# image 10/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038884_0_0_0_1_90_100_200.png: 640x512 1 Epinare, 1 Kratin5mg, 8.9ms
# image 11/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038890_0_0_0_1_75_280_200.png: 640x512 (no detections), 8.9ms
# image 12/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038890_0_0_0_1_75_300_200.png: 640x512 (no detections), 8.9ms
# image 13/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038890_0_0_0_1_75_320_200.png: 640x512 1 Beatus, 8.9ms
# image 14/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038890_0_0_0_1_75_340_200.png: 640x512 1 Beatus, 8.9ms
# image 15/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038890_0_0_0_1_90_000_200.png: 640x512 (no detections), 8.9ms
# image 16/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038890_0_0_0_1_90_020_200.png: 640x512 1 Beatus, 8.9ms
# image 17/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038890_0_0_0_1_90_040_200.png: 640x512 (no detections), 8.9ms
# image 18/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038890_0_0_0_1_90_060_200.png: 640x512 1 Beatus, 8.9ms
# image 19/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038890_0_0_0_1_90_080_200.png: 640x512 1 Beatus, 8.9ms
# image 20/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038890_0_0_0_1_90_100_200.png: 640x512 1 Beatus, 13.7ms
# image 21/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038896_0_1_0_0_90_280_200.png: 640x512 (no detections), 9.4ms
# image 22/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038896_0_1_0_0_90_300_200.png: 640x512 (no detections), 8.9ms
# image 23/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038896_0_1_0_0_90_320_200.png: 640x512 (no detections), 8.9ms
# image 24/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038896_0_1_0_0_90_340_200.png: 640x512 (no detections), 8.9ms
# image 25/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038896_0_1_0_1_70_000_200.png: 640x512 (no detections), 9.0ms
# image 26/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038896_0_1_0_1_70_020_200.png: 640x512 (no detections), 8.9ms
# image 27/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038896_0_1_0_1_70_040_200.png: 640x512 (no detections), 8.9ms
# image 28/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038896_0_1_0_1_70_060_200.png: 640x512 (no detections), 8.9ms
# image 29/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038896_0_1_0_1_70_080_200.png: 640x512 (no detections), 8.9ms
# image 30/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038896_0_1_0_1_70_100_200.png: 640x512 (no detections), 8.9ms
# image 31/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038910_0_0_0_0_90_280_200.png: 640x512 (no detections), 8.9ms
# image 32/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038910_0_0_0_0_90_300_200.png: 640x512 (no detections), 9.6ms
# image 33/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038910_0_0_0_0_90_320_200.png: 640x512 (no detections), 8.9ms
# image 34/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038910_0_0_0_0_90_340_200.png: 640x512 (no detections), 8.9ms
# image 35/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038910_0_0_0_1_70_000_200.png: 640x512 (no detections), 8.9ms
# image 36/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038910_0_0_0_1_70_020_200.png: 640x512 (no detections), 8.9ms
# image 37/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038910_0_0_0_1_70_040_200.png: 640x512 (no detections), 8.9ms
# image 38/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038910_0_0_0_1_70_060_200.png: 640x512 (no detections), 8.9ms
# image 39/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038910_0_0_0_1_70_080_200.png: 640x512 (no detections), 8.9ms
# image 40/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038910_0_0_0_1_70_100_200.png: 640x512 (no detections), 8.9ms
# image 41/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038912_0_0_0_1_75_280_200.png: 640x512 1 Kratin20mg, 9.3ms
# image 42/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038912_0_0_0_1_75_300_200.png: 640x512 1 Kratin20mg, 14.4ms
# image 43/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038912_0_0_0_1_75_320_200.png: 640x512 1 Kratin20mg, 25.7ms
# image 44/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038912_0_0_0_1_75_340_200.png: 640x512 1 Kratin20mg, 12.5ms
# image 45/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038912_0_0_0_1_90_000_200.png: 640x512 1 Kratin20mg, 12.7ms
# image 46/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038912_0_0_0_1_90_020_200.png: 640x512 1 Kratin20mg, 8.9ms
# image 47/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038912_0_0_0_1_90_040_200.png: 640x512 1 Kratin20mg, 8.9ms
# image 48/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038912_0_0_0_1_90_060_200.png: 640x512 1 Kratin20mg, 8.9ms
# image 49/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038912_0_0_0_1_90_080_200.png: 640x512 1 Kratin20mg, 8.9ms
# image 50/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038912_0_0_0_1_90_100_200.png: 640x512 1 Kratin20mg, 9.0ms
# image 51/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038913_0_0_0_1_75_280_200.png: 640x512 (no detections), 15.4ms
# image 52/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038913_0_0_0_1_75_300_200.png: 640x512 1 Kratin10mg, 8.9ms
# image 53/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038913_0_0_0_1_75_320_200.png: 640x512 1 Kratin20mg, 8.9ms
# image 54/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038913_0_0_0_1_75_340_200.png: 640x512 1 Kratin20mg, 8.9ms
# image 55/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038913_0_0_0_1_90_000_200.png: 640x512 1 Kratin20mg, 8.9ms
# image 56/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038913_0_0_0_1_90_020_200.png: 640x512 (no detections), 8.9ms
# image 57/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038913_0_0_0_1_90_040_200.png: 640x512 1 Kratin20mg, 8.9ms
# image 58/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038913_0_0_0_1_90_060_200.png: 640x512 (no detections), 8.9ms
# image 59/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038913_0_0_0_1_90_080_200.png: 640x512 (no detections), 9.8ms
# image 60/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038913_0_0_0_1_90_100_200.png: 640x512 (no detections), 12.5ms
# image 61/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038914_0_0_0_1_75_280_200.png: 640x512 1 Kratin5mg, 8.9ms
# image 62/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038914_0_0_0_1_75_300_200.png: 640x512 1 Kratin5mg, 11.9ms
# image 63/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038914_0_0_0_1_75_320_200.png: 640x512 1 Kratin5mg, 11.2ms
# image 64/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038914_0_0_0_1_75_340_200.png: 640x512 1 Kratin5mg, 8.9ms
# image 65/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038914_0_0_0_1_90_000_200.png: 640x512 1 Kratin5mg, 22.0ms
# image 66/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038914_0_0_0_1_90_020_200.png: 640x512 1 Kratin5mg, 8.9ms
# image 67/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038914_0_0_0_1_90_040_200.png: 640x512 1 Kratin5mg, 10.3ms
# image 68/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038914_0_0_0_1_90_060_200.png: 640x512 1 Kratin5mg, 10.9ms
# image 69/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038914_0_0_0_1_90_080_200.png: 640x512 1 Kratin5mg, 9.0ms
# image 70/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038914_0_0_0_1_90_100_200.png: 640x512 1 Kratin5mg, 9.0ms
# image 71/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038927_0_0_0_0_90_280_200.png: 640x512 (no detections), 9.0ms
# image 72/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038927_0_0_0_0_90_300_200.png: 640x512 (no detections), 11.0ms
# image 73/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038927_0_0_0_0_90_320_200.png: 640x512 (no detections), 8.9ms
# image 74/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038927_0_0_0_0_90_340_200.png: 640x512 (no detections), 9.0ms
# image 75/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038927_0_0_0_1_70_000_200.png: 640x512 (no detections), 8.9ms
# image 76/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038927_0_0_0_1_70_020_200.png: 640x512 (no detections), 9.0ms
# image 77/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038927_0_0_0_1_70_040_200.png: 640x512 (no detections), 11.9ms
# image 78/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038927_0_0_0_1_70_060_200.png: 640x512 (no detections), 8.9ms
# image 79/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038927_0_0_0_1_70_080_200.png: 640x512 (no detections), 12.9ms
# image 80/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038927_0_0_0_1_70_100_200.png: 640x512 (no detections), 8.9ms
# image 81/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038929_0_0_0_0_90_280_200.png: 640x512 (no detections), 8.9ms
# image 82/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038929_0_0_0_0_90_300_200.png: 640x512 (no detections), 12.0ms
# image 83/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038929_0_0_0_0_90_320_200.png: 640x512 (no detections), 8.9ms
# image 84/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038929_0_0_0_0_90_340_200.png: 640x512 (no detections), 8.9ms
# image 85/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038929_0_0_0_1_70_000_200.png: 640x512 (no detections), 17.3ms
# image 86/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038929_0_0_0_1_70_020_200.png: 640x512 (no detections), 8.9ms
# image 87/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038929_0_0_0_1_70_040_200.png: 640x512 (no detections), 8.9ms
# image 88/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038929_0_0_0_1_70_060_200.png: 640x512 (no detections), 15.4ms
# image 89/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038929_0_0_0_1_70_080_200.png: 640x512 (no detections), 16.6ms
# image 90/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038929_0_0_0_1_70_100_200.png: 640x512 (no detections), 8.9ms
# image 91/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038954_0_2_0_0_90_280_200.png: 640x512 (no detections), 8.9ms
# image 92/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038954_0_2_0_0_90_300_200.png: 640x512 (no detections), 8.9ms
# image 93/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038954_0_2_0_0_90_320_200.png: 640x512 (no detections), 8.9ms
# image 94/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038954_0_2_0_0_90_340_200.png: 640x512 (no detections), 8.9ms
# image 95/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038954_0_2_0_1_70_000_200.png: 640x512 (no detections), 8.9ms
# image 96/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038954_0_2_0_1_70_020_200.png: 640x512 (no detections), 8.9ms
# image 97/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038954_0_2_0_1_70_040_200.png: 640x512 (no detections), 8.9ms
# image 98/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038954_0_2_0_1_70_060_200.png: 640x512 (no detections), 9.9ms
# image 99/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038954_0_2_0_1_70_080_200.png: 640x512 (no detections), 8.9ms
# image 100/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038954_0_2_0_1_70_100_200.png: 640x512 (no detections), 8.9ms
# image 101/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038958_0_2_0_0_90_280_200.png: 640x512 (no detections), 8.9ms
# image 102/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038958_0_2_0_0_90_300_200.png: 640x512 (no detections), 9.1ms
# image 103/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038958_0_2_0_0_90_320_200.png: 640x512 (no detections), 8.9ms
# image 104/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038958_0_2_0_0_90_340_200.png: 640x512 (no detections), 8.9ms
# image 105/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038958_0_2_0_1_70_000_200.png: 640x512 (no detections), 9.1ms
# image 106/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038958_0_2_0_1_70_020_200.png: 640x512 (no detections), 8.9ms
# image 107/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038958_0_2_0_1_70_040_200.png: 640x512 (no detections), 8.9ms
# image 108/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038958_0_2_0_1_70_060_200.png: 640x512 (no detections), 8.9ms
# image 109/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038958_0_2_0_1_70_080_200.png: 640x512 (no detections), 8.9ms
# image 110/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038958_0_2_0_1_70_100_200.png: 640x512 (no detections), 8.9ms
# image 111/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038959_0_0_0_1_75_280_200.png: 640x512 1 biwoomi500mg, 8.9ms
# image 112/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038959_0_0_0_1_75_300_200.png: 640x512 1 biwoomi500mg, 8.9ms
# image 113/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038959_0_0_0_1_75_320_200.png: 640x512 1 biwoomi500mg, 8.9ms
# image 114/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038959_0_0_0_1_75_340_200.png: 640x512 1 biwoomi500mg, 8.9ms
# image 115/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038959_0_0_0_1_90_000_200.png: 640x512 1 biwoomi500mg, 8.9ms
# image 116/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038959_0_0_0_1_90_020_200.png: 640x512 1 biwoomi500mg, 9.8ms
# image 117/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038959_0_0_0_1_90_040_200.png: 640x512 1 biwoomi500mg, 8.9ms
# image 118/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038959_0_0_0_1_90_060_200.png: 640x512 1 biwoomi500mg, 8.9ms
# image 119/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038959_0_0_0_1_90_080_200.png: 640x512 1 biwoomi500mg, 9.0ms
# image 120/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038959_0_0_0_1_90_100_200.png: 640x512 1 biwoomi500mg, 8.9ms
# image 121/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038962_0_2_0_0_90_280_200.png: 640x512 1 Endomin 300 Premium Soft Capsule 300mg, 8.9ms
# image 122/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038962_0_2_0_0_90_300_200.png: 640x512 1 Endomin 300 Premium Soft Capsule 300mg, 8.9ms
# image 123/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038962_0_2_0_0_90_320_200.png: 640x512 1 Endomin 300 Premium Soft Capsule 300mg, 8.9ms
# image 124/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038962_0_2_0_0_90_340_200.png: 640x512 1 Endomin 300 Premium Soft Capsule 300mg, 8.9ms
# image 125/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038962_0_2_0_1_70_000_200.png: 640x512 1 Endomin 300 Premium Soft Capsule 300mg, 8.9ms
# image 126/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038962_0_2_0_1_70_020_200.png: 640x512 1 Endomin 300 Premium Soft Capsule 300mg, 8.9ms
# image 127/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038962_0_2_0_1_70_040_200.png: 640x512 1 Endomin 300 Premium Soft Capsule 300mg, 8.9ms
# image 128/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038962_0_2_0_1_70_060_200.png: 640x512 1 Endomin 300 Premium Soft Capsule 300mg, 17.5ms
# image 129/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038962_0_2_0_1_70_080_200.png: 640x512 1 Endomin 300 Premium Soft Capsule 300mg, 10.9ms
# image 130/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038962_0_2_0_1_70_100_200.png: 640x512 1 Endomin 300 Premium Soft Capsule 300mg, 8.9ms
# image 131/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038967_0_2_0_0_90_280_200.png: 640x512 (no detections), 8.9ms
# image 132/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038967_0_2_0_0_90_300_200.png: 640x512 (no detections), 9.0ms
# image 133/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038967_0_2_0_0_90_320_200.png: 640x512 (no detections), 8.9ms
# image 134/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038967_0_2_0_0_90_340_200.png: 640x512 (no detections), 8.9ms
# image 135/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038967_0_2_0_1_70_000_200.png: 640x512 (no detections), 8.9ms
# image 136/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038967_0_2_0_1_70_020_200.png: 640x512 (no detections), 8.9ms
# image 137/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038967_0_2_0_1_70_040_200.png: 640x512 (no detections), 8.9ms
# image 138/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038967_0_2_0_1_70_060_200.png: 640x512 (no detections), 8.9ms
# image 139/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038967_0_2_0_1_70_080_200.png: 640x512 (no detections), 8.9ms
# image 140/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038967_0_2_0_1_70_100_200.png: 640x512 (no detections), 8.9ms
# image 141/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038970_0_2_0_1_75_280_200.png: 640x512 1 Ranofensemi, 8.9ms
# image 142/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038970_0_2_0_1_75_300_200.png: 640x512 1 Ranofensemi, 8.9ms
# image 143/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038970_0_2_0_1_75_320_200.png: 640x512 1 Ranofensemi, 8.9ms
# image 144/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038970_0_2_0_1_75_340_200.png: 640x512 1 Ranofensemi, 9.0ms
# image 145/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038970_0_2_0_1_90_000_200.png: 640x512 1 Ranofensemi, 8.9ms
# image 146/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038970_0_2_0_1_90_020_200.png: 640x512 1 Ranofensemi, 8.9ms
# image 147/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038970_0_2_0_1_90_040_200.png: 640x512 1 Ranofensemi, 8.9ms
# image 148/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038970_0_2_0_1_90_060_200.png: 640x512 1 Ranofensemi, 8.9ms
# image 149/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038970_0_2_0_1_90_080_200.png: 640x512 1 Ranofensemi, 8.9ms
# image 150/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-038970_0_2_0_1_90_100_200.png: 640x512 1 Ranofensemi, 8.9ms
# image 151/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039021_0_2_0_0_90_280_200.png: 640x512 (no detections), 8.9ms
# image 152/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039021_0_2_0_0_90_300_200.png: 640x512 (no detections), 8.9ms
# image 153/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039021_0_2_0_0_90_320_200.png: 640x512 (no detections), 8.9ms
# image 154/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039021_0_2_0_0_90_340_200.png: 640x512 (no detections), 8.9ms
# image 155/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039021_0_2_0_1_70_000_200.png: 640x512 (no detections), 12.9ms
# image 156/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039021_0_2_0_1_70_020_200.png: 640x512 (no detections), 12.3ms
# image 157/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039021_0_2_0_1_70_040_200.png: 640x512 (no detections), 9.9ms
# image 158/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039021_0_2_0_1_70_060_200.png: 640x512 (no detections), 8.9ms
# image 159/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039021_0_2_0_1_70_080_200.png: 640x512 (no detections), 8.9ms
# image 160/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039021_0_2_0_1_70_100_200.png: 640x512 (no detections), 8.9ms
# image 161/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039036_0_1_0_0_90_280_200.png: 640x512 1 Refrega Capsules75mg, 8.9ms
# image 162/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039036_0_1_0_0_90_300_200.png: 640x512 1 Refrega Capsules75mg, 8.9ms
# image 163/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039036_0_1_0_0_90_320_200.png: 640x512 1 Refrega Capsules75mg, 8.9ms
# image 164/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039036_0_1_0_0_90_340_200.png: 640x512 1 Refrega Capsules75mg, 10.2ms
# image 165/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039036_0_1_0_1_70_000_200.png: 640x512 1 Refrega Capsules75mg, 10.1ms
# image 166/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039036_0_1_0_1_70_020_200.png: 640x512 1 Refrega Capsules75mg, 26.3ms
# image 167/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039036_0_1_0_1_70_040_200.png: 640x512 1 Refrega Capsules75mg, 8.9ms
# image 168/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039036_0_1_0_1_70_060_200.png: 640x512 1 Refrega Capsules75mg, 9.0ms
# image 169/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039036_0_1_0_1_70_080_200.png: 640x512 1 Refrega Capsules75mg, 8.9ms
# image 170/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039036_0_1_0_1_70_100_200.png: 640x512 1 Refrega Capsules75mg, 13.5ms
# image 171/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039047_0_2_0_0_90_280_200.png: 640x512 1 Refrega Capsules75mg, 9.2ms
# image 172/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039047_0_2_0_0_90_300_200.png: 640x512 (no detections), 8.9ms
# image 173/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039047_0_2_0_0_90_320_200.png: 640x512 (no detections), 9.8ms
# image 174/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039047_0_2_0_0_90_340_200.png: 640x512 1 reselton capsule6.0mg, 10.0ms
# image 175/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039047_0_2_0_1_70_000_200.png: 640x512 1 Refrega Capsules75mg, 8.9ms
# image 176/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039047_0_2_0_1_70_020_200.png: 640x512 1 Refrega Capsules75mg, 8.9ms
# image 177/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039047_0_2_0_1_70_040_200.png: 640x512 1 Refrega Capsules75mg, 8.9ms
# image 178/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039047_0_2_0_1_70_060_200.png: 640x512 1 Refrega Capsules75mg, 1 reselton capsule6.0mg, 8.9ms
# image 179/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039047_0_2_0_1_70_080_200.png: 640x512 1 Refrega Capsules75mg, 1 reselton capsule6.0mg, 10.1ms
# image 180/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039047_0_2_0_1_70_100_200.png: 640x512 1 Refrega Capsules75mg, 8.9ms
# image 181/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039104_0_0_0_1_75_280_200.png: 640x512 1 Bearrotan50mg, 8.9ms
# image 182/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039104_0_0_0_1_75_300_200.png: 640x512 1 Bearrotan50mg, 8.9ms
# image 183/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039104_0_0_0_1_75_320_200.png: 640x512 1 Bearrotan50mg, 8.9ms
# image 184/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039104_0_0_0_1_75_340_200.png: 640x512 1 Bearrotan50mg, 9.0ms
# image 185/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039104_0_0_0_1_90_000_200.png: 640x512 1 Bearrotan50mg, 13.4ms
# image 186/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039104_0_0_0_1_90_020_200.png: 640x512 1 Bearrotan50mg, 10.5ms
# image 187/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039104_0_0_0_1_90_040_200.png: 640x512 1 Bearrotan50mg, 11.8ms
# image 188/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039104_0_0_0_1_90_060_200.png: 640x512 1 Bearrotan50mg, 11.4ms
# image 189/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039104_0_0_0_1_90_080_200.png: 640x512 1 Bearrotan50mg, 10.4ms
# image 190/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039104_0_0_0_1_90_100_200.png: 640x512 1 Bearrotan50mg, 9.0ms
# image 191/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039108_0_0_0_1_75_280_200.png: 640x512 1 Beatus, 8.9ms
# image 192/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039108_0_0_0_1_75_300_200.png: 640x512 1 Beatus, 8.9ms
# image 193/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039108_0_0_0_1_75_320_200.png: 640x512 1 Beatus, 8.9ms
# image 194/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039108_0_0_0_1_75_340_200.png: 640x512 1 Beatus, 8.9ms
# image 195/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039108_0_0_0_1_90_000_200.png: 640x512 1 Beatus, 8.9ms
# image 196/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039108_0_0_0_1_90_020_200.png: 640x512 1 Beatus, 8.9ms
# image 197/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039108_0_0_0_1_90_040_200.png: 640x512 1 Beatus, 10.2ms
# image 198/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039108_0_0_0_1_90_060_200.png: 640x512 1 Beatus, 8.9ms
# image 199/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039108_0_0_0_1_90_080_200.png: 640x512 1 Beatus, 8.9ms
# image 200/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039108_0_0_0_1_90_100_200.png: 640x512 1 Beatus, 8.9ms
# image 201/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039123_0_2_0_1_75_280_200.png: 640x512 1 Phytarotene2mg, 16.0ms
# image 202/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039123_0_2_0_1_75_300_200.png: 640x512 1 Phytarotene2mg, 8.9ms
# image 203/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039123_0_2_0_1_75_320_200.png: 640x512 1 Phytarotene2mg, 8.9ms
# image 204/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039123_0_2_0_1_75_340_200.png: 640x512 1 Phytarotene2mg, 8.9ms
# image 205/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039123_0_2_0_1_90_000_200.png: 640x512 1 Phytarotene2mg, 8.9ms
# image 206/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039123_0_2_0_1_90_020_200.png: 640x512 1 Phytarotene2mg, 8.9ms
# image 207/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039123_0_2_0_1_90_040_200.png: 640x512 1 Phytarotene2mg, 8.9ms
# image 208/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039123_0_2_0_1_90_060_200.png: 640x512 1 Phytarotene2mg, 8.9ms
# image 209/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039123_0_2_0_1_90_080_200.png: 640x512 1 Phytarotene2mg, 9.0ms
# image 210/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039123_0_2_0_1_90_100_200.png: 640x512 1 Phytarotene2mg, 8.9ms
# image 211/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039136_0_0_0_0_75_280_200.png: 640x512 1 Rukio10mg, 9.6ms
# image 212/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039136_0_0_0_0_75_300_200.png: 640x512 1 Rukio10mg, 8.9ms
# image 213/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039136_0_0_0_0_75_320_200.png: 640x512 1 Rukio10mg, 8.9ms
# image 214/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039136_0_0_0_0_75_340_200.png: 640x512 1 Rukio10mg, 8.9ms
# image 215/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039136_0_0_0_0_90_000_200.png: 640x512 1 Rukio10mg, 8.9ms
# image 216/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039136_0_0_0_0_90_020_200.png: 640x512 1 Rukio10mg, 8.9ms
# image 217/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039136_0_0_0_0_90_040_200.png: 640x512 1 Rukio10mg, 8.9ms
# image 218/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039136_0_0_0_0_90_060_200.png: 640x512 1 Rukio10mg, 9.0ms
# image 219/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039136_0_0_0_0_90_080_200.png: 640x512 1 Rukio10mg, 8.9ms
# image 220/220 /content/drive/MyDrive/Colab Notebooks/competition/test/yolotest/validlabel/K-039136_0_0_0_0_90_100_200.png: 640x512 1 Rukio10mg, 8.9ms
# Speed: 0.7ms pre-process, 10.0ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %% [markdown]
# # 아래코드는 실행이 안되는거같고 자른거 확인해 보려면 학습 끝낸 로그창 가장 아래에 어느 폴더에 저장되는지 들어가서 확인할 수 있음

# %%
# 테스트 결과 확인해보기

import glob
from IPython.display import Image, display

test_exp_num = 2

# if not os.path.exists('/content/drive/MyDrive/yolov5/runs/detect/exp' + str(test_exp_num) + '/') :
if not os.path.exists('/content/drive/MyDrive/yolov5/runs/detect/exp/') :
  raise Exception('test_exp_num 을 다시 확인하세요.')

# for imageName in glob.glob('/content/drive/MyDrive/yolov5/runs/detect/exp' + str(test_exp_num) + '/*.jpg'): #assuming JPG
for imageName in glob.glob('/content/drive/MyDrive/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# ## 7. 학습한 베스트 모델 저장

# %%
# 학습한 베스트 모델 저장
from google.colab import files
files.download('./runs/train/exp' + str(test_exp_num) + '/weights/best.pt')
