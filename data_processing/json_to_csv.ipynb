# %%
import pandas as pd
import json
import pathlib
path = pathlib.Path('C:/dev/github/final/Final_project/data')

# %%
path = pathlib.Path('C:/dev/github/final/Final_project/data')
str(path)
# Out:
# 'C:\\dev\\github\\final\\Final_project\\data'

# %% [markdown]
# # JSON_images

# %% [markdown]
# ## TL_단일 1~5

# %%
def to_dataframe(path):
    path_list = path.glob('label/*/*/*')
    df_columns =[]

    for paths in path_list:
        json_path = paths.glob('*.json')
        for j in json_path:  # json_path 경로안에 있는 j 하나씩 읽음 
            with open(j, encoding = 'utf-8') as json_file:
                data = json.load(json_file)['images'][0]
                df_columns.append(data)

    df = pd.DataFrame(df_columns)
    return df

# %%
df = to_dataframe(path)
df.head()
# Out:
#                          file_name  width  height
# 0  K-000059_0_0_0_0_60_000_200.png    976    1280  \
# 1  K-000059_0_0_0_0_60_020_200.png    976    1280
# 2  K-000059_0_0_0_0_60_040_200.png    976    1280
# 3  K-000059_0_0_0_0_60_060_200.png    976    1280
# 4  K-000059_0_0_0_0_60_080_200.png    976    1280
#
#                            imgfile    drug_N drug_S back_color drug_dir
# 0  K-000059_0_0_0_0_60_000_200.png  K-000059   정상알약     검은색 배경       앞면  \
# 1  K-000059_0_0_0_0_60_020_200.png  K-000059   정상알약     검은색 배경       앞면
# 2  K-000059_0_0_0_0_60_040_200.png  K-000059   정상알약     검은색 배경       앞면
# 3  K-000059_0_0_0_0_60_060_200.png  K-000059   정상알약     검은색 배경       앞면
# 4  K-000059_0_0_0_0_60_080_200.png  K-000059   정상알약     검은색 배경       앞면
#
#   light_color  camera_la  ...  line_back  img_regist_ts form_code_name
# 0         전구색         60  ...                  20041222             나정  \
# 1         전구색         60  ...                  20041222             나정
# ...

# %%
df.shape
# Out:
# (323568, 50)

# %% [markdown]
# ## TL_단일 6~10

# %%
df_6to10 = to_dataframe(path)
df_6to10.head(10)
# Out:
#                          file_name  width  height
# 0  K-019461_0_0_0_0_60_000_200.png    976    1280  \
# 1  K-019461_0_0_0_0_60_020_200.png    976    1280
# 2  K-019461_0_0_0_0_60_040_200.png    976    1280
# 3  K-019461_0_0_0_0_60_060_200.png    976    1280
# 4  K-019461_0_0_0_0_60_080_200.png    976    1280
# 5  K-019461_0_0_0_0_60_100_200.png    976    1280
# 6  K-019461_0_0_0_0_60_120_200.png    976    1280
# 7  K-019461_0_0_0_0_60_140_200.png    976    1280
# 8  K-019461_0_0_0_0_60_160_200.png    976    1280
# 9  K-019461_0_0_0_0_60_180_200.png    976    1280
#
#                            imgfile    drug_N drug_S back_color drug_dir
# 0  K-019461_0_0_0_0_60_000_200.png  K-019461   정상알약     검은색 배경       앞면  \
# 1  K-019461_0_0_0_0_60_020_200.png  K-019461   정상알약     검은색 배경       앞면
# 2  K-019461_0_0_0_0_60_040_200.png  K-019461   정상알약     검은색 배경       앞면
# 3  K-019461_0_0_0_0_60_060_200.png  K-019461   정상알약     검은색 배경       앞면
# ...

# %%
df_6to10.shape
# Out:
# (323784, 50)

# %% [markdown]
# ## TL_단일 11~15

# %%
df_11to15 = to_dataframe(path)
df_11to15
# Out:
#                               file_name  width  height
# 0       K-022749_0_0_0_0_60_000_200.png    976    1280  \
# 1       K-022749_0_0_0_0_60_020_200.png    976    1280
# 2       K-022749_0_0_0_0_60_040_200.png    976    1280
# 3       K-022749_0_0_0_0_60_060_200.png    976    1280
# 4       K-022749_0_0_0_0_60_080_200.png    976    1280
# ...                                 ...    ...     ...
# 323779  K-034568_0_2_1_2_90_260_200.png    976    1280
# 323780  K-034568_0_2_1_2_90_280_200.png    976    1280
# 323781  K-034568_0_2_1_2_90_300_200.png    976    1280
# 323782  K-034568_0_2_1_2_90_320_200.png    976    1280
# 323783  K-034568_0_2_1_2_90_340_200.png    976    1280
#
#                                 imgfile    drug_N drug_S back_color drug_dir
# 0       K-022749_0_0_0_0_60_000_200.png  K-022749   정상알약     검은색 배경       앞면  \
# 1       K-022749_0_0_0_0_60_020_200.png  K-022749   정상알약     검은색 배경       앞면
# ...

# %% [markdown]
# ## TL_단일 16~20

# %%
df_16to20 = to_dataframe(path)
df_16to20
# Out:
#                               file_name  width  height
# 0       K-034569_0_0_0_0_60_000_200.png    976    1280  \
# 1       K-034569_0_0_0_0_60_020_200.png    976    1280
# 2       K-034569_0_0_0_0_60_040_200.png    976    1280
# 3       K-034569_0_0_0_0_60_060_200.png    976    1280
# 4       K-034569_0_0_0_0_60_080_200.png    976    1280
# ...                                 ...    ...     ...
# 323677  K-059586_0_2_1_2_90_260_200.png    976    1280
# 323678  K-059586_0_2_1_2_90_280_200.png    976    1280
# 323679  K-059586_0_2_1_2_90_300_200.png    976    1280
# 323680  K-059586_0_2_1_2_90_320_200.png    976    1280
# 323681  K-059586_0_2_1_2_90_340_200.png    976    1280
#
#                                 imgfile    drug_N drug_S back_color drug_dir
# 0       K-034569_0_0_0_0_60_000_200.png  K-034569   정상알약     검은색 배경       앞면  \
# 1       K-034569_0_0_0_0_60_020_200.png  K-034569   정상알약     검은색 배경       앞면
# ...

# %% [markdown]
# ## TL_단일 21~25

# %%
df_21to25 = to_dataframe(path)
df_21to25
# Out:
#                               file_name  width  height
# 0       K-000027_0_2_0_0_75_000_200.png    976    1280  \
# 1       K-000027_0_2_0_0_75_020_200.png    976    1280
# 2       K-000027_0_2_0_0_75_040_200.png    976    1280
# 3       K-000027_0_2_0_0_75_060_200.png    976    1280
# 4       K-000027_0_2_0_0_75_080_200.png    976    1280
# ...                                 ...    ...     ...
# 131539  K-003354_0_2_1_2_90_260_200.png    976    1280
# 131540  K-003354_0_2_1_2_90_280_200.png    976    1280
# 131541  K-003354_0_2_1_2_90_300_200.png    976    1280
# 131542  K-003354_0_2_1_2_90_320_200.png    976    1280
# 131543  K-003354_0_2_1_2_90_340_200.png    976    1280
#
#                                 imgfile    drug_N drug_S back_color drug_dir
# 0       K-000027_0_2_0_0_75_000_200.png  K-000027   정상알약     연회색 배경       앞면  \
# 1       K-000027_0_2_0_0_75_020_200.png  K-000027   정상알약     연회색 배경       앞면
# ...

# %% [markdown]
# ## TL_단일 26~30

# %%
df_26to30 = to_dataframe(path)
df_26to30
# Out:
#                              file_name  width  height
# 0      K-003364_0_0_0_0_75_000_200.png    976    1280  \
# 1      K-003364_0_0_0_0_75_020_200.png    976    1280
# 2      K-003364_0_0_0_0_75_040_200.png    976    1280
# 3      K-003364_0_0_0_0_75_060_200.png    976    1280
# 4      K-003364_0_0_0_0_75_080_200.png    976    1280
# ...                                ...    ...     ...
# 95467  K-006633_0_2_1_2_90_260_200.png    976    1280
# 95468  K-006633_0_2_1_2_90_280_200.png    976    1280
# 95469  K-006633_0_2_1_2_90_300_200.png    976    1280
# 95470  K-006633_0_2_1_2_90_320_200.png    976    1280
# 95471  K-006633_0_2_1_2_90_340_200.png    976    1280
#
#                                imgfile    drug_N drug_S back_color drug_dir
# 0      K-003364_0_0_0_0_75_000_200.png  K-003364   정상알약     검은색 배경       앞면  \
# 1      K-003364_0_0_0_0_75_020_200.png  K-003364   정상알약     검은색 배경       앞면
# 2      K-003364_0_0_0_0_75_040_200.png  K-003364   정상알약     검은색 배경       앞면
# ...

# %% [markdown]
# ## TL_단일 31~40

# %%
df_31to40 = to_dataframe(path)
df_31to40
# Out:
#                               file_name  width  height
# 0       K-006656_0_2_0_0_75_000_200.png    976    1280  \
# 1       K-006656_0_2_0_0_75_020_200.png    976    1280
# 2       K-006656_0_2_0_0_75_040_200.png    976    1280
# 3       K-006656_0_2_0_0_75_060_200.png    976    1280
# 4       K-006656_0_2_0_0_75_080_200.png    976    1280
# ...                                 ...    ...     ...
# 202169  K-014267_0_2_1_2_90_260_200.png    976    1280
# 202170  K-014267_0_2_1_2_90_280_200.png    976    1280
# 202171  K-014267_0_2_1_2_90_300_200.png    976    1280
# 202172  K-014267_0_2_1_2_90_320_200.png    976    1280
# 202173  K-014267_0_2_1_2_90_340_200.png    976    1280
#
#                                 imgfile    drug_N drug_S back_color drug_dir
# 0       K-006656_0_2_0_0_75_000_200.png  K-006656   정상알약     연회색 배경       앞면  \
# 1       K-006656_0_2_0_0_75_020_200.png  K-006656   정상알약     연회색 배경       앞면
# ...

# %% [markdown]
# ## TL_단일 41~50

# %%
df_41to50 = to_dataframe(path)
df_41to50
# Out:
#                               file_name  width  height
# 0       K-014271_0_0_0_0_75_000_200.png    976    1280  \
# 1       K-014271_0_0_0_0_75_020_200.png    976    1280
# 2       K-014271_0_0_0_0_75_040_200.png    976    1280
# 3       K-014271_0_0_0_0_75_060_200.png    976    1280
# 4       K-014271_0_0_0_0_75_080_200.png    976    1280
# ...                                 ...    ...     ...
# 183379  K-020973_0_2_1_2_90_260_200.png    976    1280
# 183380  K-020973_0_2_1_2_90_280_200.png    976    1280
# 183381  K-020973_0_2_1_2_90_300_200.png    976    1280
# 183382  K-020973_0_2_1_2_90_320_200.png    976    1280
# 183383  K-020973_0_2_1_2_90_340_200.png    976    1280
#
#                                 imgfile    drug_N drug_S back_color drug_dir
# 0       K-014271_0_0_0_0_75_000_200.png  K-014271   정상알약     검은색 배경       앞면  \
# 1       K-014271_0_0_0_0_75_020_200.png  K-014271   정상알약     검은색 배경       앞면
# ...

# %% [markdown]
# ## TL_단일 51~60

# %%
df_51to60 = to_dataframe(path)
df_51to60
# Out:
#                               file_name  width  height
# 0       K-020975_0_0_0_0_75_000_200.png    976    1280  \
# 1       K-020975_0_0_0_0_75_020_200.png    976    1280
# 2       K-020975_0_0_0_0_75_040_200.png    976    1280
# 3       K-020975_0_0_0_0_75_060_200.png    976    1280
# 4       K-020975_0_0_0_0_75_080_200.png    976    1280
# ...                                 ...    ...     ...
# 189643  K-027777_0_2_1_2_90_260_200.png    976    1280
# 189644  K-027777_0_2_1_2_90_280_200.png    976    1280
# 189645  K-027777_0_2_1_2_90_300_200.png    976    1280
# 189646  K-027777_0_2_1_2_90_320_200.png    976    1280
# 189647  K-027777_0_2_1_2_90_340_200.png    976    1280
#
#                                 imgfile    drug_N drug_S back_color drug_dir
# 0       K-020975_0_0_0_0_75_000_200.png  K-020975   정상알약     검은색 배경       앞면  \
# 1       K-020975_0_0_0_0_75_020_200.png  K-020975   정상알약     검은색 배경       앞면
# ...

# %% [markdown]
# ## TL_단일 61~70

# %%
df_61to70 = to_dataframe(path)
df_61to70
# Out:
#                               file_name  width  height
# 0       K-027815_0_2_0_0_75_000_200.png    976    1280  \
# 1       K-027815_0_2_0_0_75_020_200.png    976    1280
# 2       K-027815_0_2_0_0_75_040_200.png    976    1280
# 3       K-027815_0_2_0_0_75_060_200.png    976    1280
# 4       K-027815_0_2_0_0_75_080_200.png    976    1280
# ...                                 ...    ...     ...
# 178087  K-032642_0_0_1_2_90_260_200.png    976    1280
# 178088  K-032642_0_0_1_2_90_280_200.png    976    1280
# 178089  K-032642_0_0_1_2_90_300_200.png    976    1280
# 178090  K-032642_0_0_1_2_90_320_200.png    976    1280
# 178091  K-032642_0_0_1_2_90_340_200.png    976    1280
#
#                                 imgfile    drug_N drug_S back_color drug_dir
# 0       K-027815_0_2_0_0_75_000_200.png  K-027815   정상알약     연회색 배경       앞면  \
# 1       K-027815_0_2_0_0_75_020_200.png  K-027815   정상알약     연회색 배경       앞면
# ...

# %% [markdown]
# ## TL_단일 71~81

# %%
df_71to81 = to_dataframe(path)
df_71to81
# Out:
#                               file_name  width  height
# 0       K-032657_0_0_0_0_75_000_200.png    976    1280  \
# 1       K-032657_0_0_0_0_75_020_200.png    976    1280
# 2       K-032657_0_0_0_0_75_040_200.png    976    1280
# 3       K-032657_0_0_0_0_75_060_200.png    976    1280
# 4       K-032657_0_0_0_0_75_080_200.png    976    1280
# ...                                 ...    ...     ...
# 176790  K-039147_0_2_1_2_90_260_200.png    976    1280
# 176791  K-039147_0_2_1_2_90_280_200.png    976    1280
# 176792  K-039147_0_2_1_2_90_300_200.png    976    1280
# 176793  K-039147_0_2_1_2_90_320_200.png    976    1280
# 176794  K-039147_0_2_1_2_90_340_200.png    976    1280
#
#                                 imgfile    drug_N drug_S back_color drug_dir
# 0       K-032657_0_0_0_0_75_000_200.png  K-032657   정상알약     검은색 배경       앞면  \
# 1       K-032657_0_0_0_0_75_020_200.png  K-032657   정상알약     검은색 배경       앞면
# ...

# %% [markdown]
# ## Data frame merge

# %%
df_merged_1to15 = pd.concat([df, df_6to10, df_11to15], ignore_index = True)
df_merged_1to15.head()
# Out:
#                          file_name  width  height
# 0  K-000059_0_0_0_0_60_000_200.png    976    1280  \
# 1  K-000059_0_0_0_0_60_020_200.png    976    1280
# 2  K-000059_0_0_0_0_60_040_200.png    976    1280
# 3  K-000059_0_0_0_0_60_060_200.png    976    1280
# 4  K-000059_0_0_0_0_60_080_200.png    976    1280
#
#                            imgfile    drug_N drug_S back_color drug_dir
# 0  K-000059_0_0_0_0_60_000_200.png  K-000059   정상알약     검은색 배경       앞면  \
# 1  K-000059_0_0_0_0_60_020_200.png  K-000059   정상알약     검은색 배경       앞면
# 2  K-000059_0_0_0_0_60_040_200.png  K-000059   정상알약     검은색 배경       앞면
# 3  K-000059_0_0_0_0_60_060_200.png  K-000059   정상알약     검은색 배경       앞면
# 4  K-000059_0_0_0_0_60_080_200.png  K-000059   정상알약     검은색 배경       앞면
#
#   light_color  camera_la  ...  line_back  img_regist_ts form_code_name
# 0         전구색         60  ...                  20041222             나정  \
# 1         전구색         60  ...                  20041222             나정
# ...

# %%
df_merged_1to15.shape
# Out:
# (971136, 50)

# %%
df_merged_16to30 = pd.concat([df_16to20, df_21to25, df_26to30], ignore_index = True)
df_merged_16to30
# Out:
#                               file_name  width  height
# 0       K-034569_0_0_0_0_60_000_200.png    976    1280  \
# 1       K-034569_0_0_0_0_60_020_200.png    976    1280
# 2       K-034569_0_0_0_0_60_040_200.png    976    1280
# 3       K-034569_0_0_0_0_60_060_200.png    976    1280
# 4       K-034569_0_0_0_0_60_080_200.png    976    1280
# ...                                 ...    ...     ...
# 550693  K-006633_0_2_1_2_90_260_200.png    976    1280
# 550694  K-006633_0_2_1_2_90_280_200.png    976    1280
# 550695  K-006633_0_2_1_2_90_300_200.png    976    1280
# 550696  K-006633_0_2_1_2_90_320_200.png    976    1280
# 550697  K-006633_0_2_1_2_90_340_200.png    976    1280
#
#                                 imgfile    drug_N drug_S back_color drug_dir
# 0       K-034569_0_0_0_0_60_000_200.png  K-034569   정상알약     검은색 배경       앞면  \
# 1       K-034569_0_0_0_0_60_020_200.png  K-034569   정상알약     검은색 배경       앞면
# ...

# %%
df_merged_31to60 = pd.concat([df_31to40, df_41to50, df_51to60], ignore_index = True)
df_merged_31to60
# Out:
#                               file_name  width  height
# 0       K-006656_0_2_0_0_75_000_200.png    976    1280  \
# 1       K-006656_0_2_0_0_75_020_200.png    976    1280
# 2       K-006656_0_2_0_0_75_040_200.png    976    1280
# 3       K-006656_0_2_0_0_75_060_200.png    976    1280
# 4       K-006656_0_2_0_0_75_080_200.png    976    1280
# ...                                 ...    ...     ...
# 575201  K-027777_0_2_1_2_90_260_200.png    976    1280
# 575202  K-027777_0_2_1_2_90_280_200.png    976    1280
# 575203  K-027777_0_2_1_2_90_300_200.png    976    1280
# 575204  K-027777_0_2_1_2_90_320_200.png    976    1280
# 575205  K-027777_0_2_1_2_90_340_200.png    976    1280
#
#                                 imgfile    drug_N drug_S back_color drug_dir
# 0       K-006656_0_2_0_0_75_000_200.png  K-006656   정상알약     연회색 배경       앞면  \
# 1       K-006656_0_2_0_0_75_020_200.png  K-006656   정상알약     연회색 배경       앞면
# ...

# %%
df_merged_61to81 = pd.concat([df_61to70, df_71to81], ignore_index = True)
df_merged_61to81
# Out:
#                               file_name  width  height
# 0       K-027815_0_2_0_0_75_000_200.png    976    1280  \
# 1       K-027815_0_2_0_0_75_020_200.png    976    1280
# 2       K-027815_0_2_0_0_75_040_200.png    976    1280
# 3       K-027815_0_2_0_0_75_060_200.png    976    1280
# 4       K-027815_0_2_0_0_75_080_200.png    976    1280
# ...                                 ...    ...     ...
# 354882  K-039147_0_2_1_2_90_260_200.png    976    1280
# 354883  K-039147_0_2_1_2_90_280_200.png    976    1280
# 354884  K-039147_0_2_1_2_90_300_200.png    976    1280
# 354885  K-039147_0_2_1_2_90_320_200.png    976    1280
# 354886  K-039147_0_2_1_2_90_340_200.png    976    1280
#
#                                 imgfile    drug_N drug_S back_color drug_dir
# 0       K-027815_0_2_0_0_75_000_200.png  K-027815   정상알약     연회색 배경       앞면  \
# 1       K-027815_0_2_0_0_75_020_200.png  K-027815   정상알약     연회색 배경       앞면
# ...

# %% [markdown]
# ## CSV 저장

# %%
# %pwd
# Out:
# 'c:\\dev\\github\\final\\collaborative\\final_project\\.github\\ISSUE_TEMPLATE'

# %%
# %cd c:/dev/github/final/Final_project/data
# Out:
# c:\dev\github\final\Final_project\data

# %%
df_merged_1to15.to_csv('TL_1to15.csv')

# %%
df_merged_16to30.to_csv('TL_16to30.csv')

# %%
df_merged_31to60.to_csv('TL_31to60.csv')

# %%
df_merged_61to81.to_csv('TL_61to81.csv')

# %%
import pandas as pd
import json
import pathlib

# %%
# %pwd
# Out:
# 'c:\\dev\\github\\final\\Final_project\\data'

# %%
df_merged_1to15 = pd.read_csv('TL_1to15.csv')
df_merged_16to30 = pd.read_csv('TL_16to30.csv')
df_merged_31to60 = pd.read_csv('TL_31to60.csv')
df_merged_61to81 = pd.read_csv('TL_61to81.csv')
# Out:
# C:\Users\유준선\AppData\Local\Temp\ipykernel_16844\2197832414.py:1: DtypeWarning: Columns (28,29,33,37,39,40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_merged_1to15 = pd.read_csv('TL_1to15.csv')
# C:\Users\유준선\AppData\Local\Temp\ipykernel_16844\2197832414.py:2: DtypeWarning: Columns (19,24,29,38,39,40,43,44,45,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_merged_16to30 = pd.read_csv('TL_16to30.csv')
# C:\Users\유준선\AppData\Local\Temp\ipykernel_16844\2197832414.py:3: DtypeWarning: Columns (23,24,29,38,39,40,43,44,45,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_merged_31to60 = pd.read_csv('TL_31to60.csv')
# C:\Users\유준선\AppData\Local\Temp\ipykernel_16844\2197832414.py:4: DtypeWarning: Columns (29,39,44,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_merged_61to81 = pd.read_csv('TL_61to81.csv')

# %%
df_img_json = pd.concat([df_merged_1to15, df_merged_16to30, df_merged_31to60, df_merged_61to81], ignore_index = True)
df_img_json
# Out:
#          Unnamed: 0                        file_name  width  height
# 0                 0  K-000059_0_0_0_0_60_000_200.png    976    1280  \
# 1                 1  K-000059_0_0_0_0_60_020_200.png    976    1280
# 2                 2  K-000059_0_0_0_0_60_040_200.png    976    1280
# 3                 3  K-000059_0_0_0_0_60_060_200.png    976    1280
# 4                 4  K-000059_0_0_0_0_60_080_200.png    976    1280
# ...             ...                              ...    ...     ...
# 2451922      354882  K-039147_0_2_1_2_90_260_200.png    976    1280
# 2451923      354883  K-039147_0_2_1_2_90_280_200.png    976    1280
# 2451924      354884  K-039147_0_2_1_2_90_300_200.png    976    1280
# 2451925      354885  K-039147_0_2_1_2_90_320_200.png    976    1280
# 2451926      354886  K-039147_0_2_1_2_90_340_200.png    976    1280
#
#                                  imgfile    drug_N drug_S back_color drug_dir
# ...

# %%
df_img_json.to_csv('df_img_json.csv')

# %% [markdown]
# # JSON_annotations

# %%
import pandas as pd
import json
import pathlib

# %%
def to_dataframe(path):
    path_list = path.glob('label/*/*/*')
    df_columns =[]

    for paths in path_list:
        json_path = paths.glob('*.json')
        for j in json_path:  # json_path 경로안에 있는 j 하나씩 읽음 
            with open(j, encoding = 'utf-8') as json_file:
                data = json.load(json_file)['annotations'][0]
                df_columns.append(data)

    df = pd.DataFrame(df_columns)
    return df

# %%
path = pathlib.Path('C:/dev/github/final/Final_project/data')
path
# Out:
# WindowsPath('C:/dev/github/final/Final_project/data')

# %%
df_ann_1to5 = to_dataframe(path)
df_ann_1to5  # TL_부터 입력됨
# Out:
#           area  iscrowd                  bbox  category_id  ignore
# 0        79508        0  [375, 474, 286, 278]            1       0  \
# 1        78668        0  [382, 482, 284, 277]            1       0
# 2        79242        0  [386, 491, 281, 282]            1       0
# 3        79524        0  [385, 502, 282, 282]            1       0
# 4        79520        0  [378, 512, 284, 280]            1       0
# ...        ...      ...                   ...          ...     ...
# 323563  109552        0  [350, 443, 334, 328]            1       0
# 323564  106982        0  [372, 432, 298, 359]            1       0
# 323565   95381        0  [394, 431, 253, 377]            1       0
# 323566   95882        0  [393, 438, 251, 382]            1       0
# 323567  108780        0  [364, 451, 294, 370]            1       0
#
#        segmentation  id  image_id
# 0                []   1         1
# 1                []   1         1
# 2                []   1         1
# ...

# %%
df_ann_6to10 = to_dataframe(path)
df_ann_6to10
# Out:
#           area  iscrowd                  bbox  category_id  ignore
# 0        50838        0  [408, 519, 229, 222]            1       0  \
# 1        51282        0  [405, 528, 231, 222]            1       0
# 2        50600        0  [407, 535, 230, 220]            1       0
# 3        51714        0  [398, 541, 234, 221]            1       0
# 4        50600        0  [394, 549, 230, 220]            1       0
# ...        ...      ...                   ...          ...     ...
# 323779  118038        0  [318, 479, 382, 309]            1       0
# 323780  125060        0  [334, 449, 338, 370]            1       0
# 323781  112860        0  [356, 421, 270, 418]            1       0
# 323782  104247        0  [364, 416, 243, 429]            1       0
# 323783  117160        0  [337, 424, 290, 404]            1       0
#
#        segmentation  id  image_id
# 0                []   1         1
# 1                []   1         1
# 2                []   1         1
# ...

# %%
df_ann_11to15 = to_dataframe(path)
df_ann_11to15
# Out:
#           area  iscrowd                  bbox  category_id  ignore
# 0        64008        0  [345, 461, 254, 252]            1       0  \
# 1        62248        0  [368, 458, 251, 248]            1       0
# 2        63246        0  [382, 458, 254, 249]            1       0
# 3        64000        0  [397, 467, 256, 250]            1       0
# 4        64005        0  [412, 477, 255, 251]            1       0
# ...        ...      ...                   ...          ...     ...
# 323779   90300        0  [360, 412, 215, 420]            1       0
# 323780  102362        0  [340, 415, 254, 403]            1       0
# 323781  119385        0  [310, 416, 315, 379]            1       0
# 323782  117342        0  [285, 439, 369, 318]            1       0
# 323783   96957        0  [275, 467, 399, 243]            1       0
#
#        segmentation  id  image_id
# 0                []   1         1
# 1                []   1         1
# 2                []   1         1
# ...

# %%
df_ann_16to20 = to_dataframe(path)
df_ann_16to20
# Out:
#           area  iscrowd                  bbox  category_id  ignore
# 0        88722        0  [336, 454, 318, 279]            1       0  \
# 1        76489        0  [312, 485, 343, 223]            1       0
# 2        70380        0  [298, 493, 345, 204]            1       0
# 3        79134        0  [300, 469, 327, 242]            1       0
# 4        82026        0  [316, 445, 294, 279]            1       0
# ...        ...      ...                   ...          ...     ...
# 323677  101258        0  [350, 464, 257, 394]            1       0
# 323678   79420        0  [372, 435, 190, 418]            1       0
# 323679   96577        0  [340, 437, 247, 391]            1       0
# 323680  111180        0  [302, 449, 327, 340]            1       0
# 323681  107904        0  [277, 470, 384, 281]            1       0
#
#        segmentation  id  image_id
# 0                []   1         1
# 1                []   1         1
# 2                []   1         1
# ...

# %%
df_ann_21to25 = to_dataframe(path)
df_ann_21to25
# Out:
#           area  iscrowd                  bbox  category_id  ignore
# 0        79515        0  [294, 475, 285, 279]            1       0  \
# 1        75900        0  [303, 461, 275, 276]            1       0
# 2        77006        0  [313, 452, 278, 277]            1       0
# 3        76452        0  [326, 445, 276, 277]            1       0
# 4        74528        0  [343, 445, 272, 274]            1       0
# ...        ...      ...                   ...          ...     ...
# 131539   97250        0  [386, 436, 250, 389]            1       0
# 131540  116316        0  [348, 454, 324, 359]            1       0
# 131541  124410        0  [322, 472, 377, 330]            1       0
# 131542  106134        0  [308, 503, 399, 266]            1       0
# 131543   87344        0  [296, 534, 412, 212]            1       0
#
#        segmentation  id  image_id
# 0                []   1         1
# 1                []   1         1
# 2                []   1         1
# ...

# %%
df_ann_26to30 = to_dataframe(path)
df_ann_26to30
# Out:
#          area  iscrowd                  bbox  category_id  ignore
# 0       38793        0  [348, 532, 193, 201]            1       0  \
# 1       38805        0  [340, 523, 195, 199]            1       0
# 2       38610        0  [339, 509, 195, 198]            1       0
# 3       39200        0  [340, 495, 196, 200]            1       0
# 4       38412        0  [350, 487, 194, 198]            1       0
# ...       ...      ...                   ...          ...     ...
# 95467  152736        0  [352, 474, 344, 444]            1       0
# 95468  164352        0  [293, 507, 428, 384]            1       0
# 95469  134850        0  [259, 546, 465, 290]            1       0
# 95470   96432        0  [232, 584, 492, 196]            1       0
# 95471  127788        0  [229, 524, 463, 276]            1       0
#
#       segmentation  id  image_id
# 0               []   1         1
# 1               []   1         1
# 2               []   1         1
# 3               []   1         1
# ...

# %%
df_ann_31to40 = to_dataframe(path)
df_ann_31to40
# Out:
#           area  iscrowd                  bbox  category_id  ignore
# 0        44325        0  [340, 494, 225, 197]            1       0  \
# 1        45435        0  [362, 473, 195, 233]            1       0
# 2        40014        0  [386, 465, 162, 247]            1       0
# 3        32512        0  [409, 458, 127, 256]            1       0
# 4        42720        0  [395, 469, 178, 240]            1       0
# ...        ...      ...                   ...          ...     ...
# 202169  104580        0  [343, 524, 332, 315]            1       0
# 202170  105270        0  [349, 494, 290, 363]            1       0
# 202171  100224        0  [352, 476, 261, 384]            1       0
# 202172  100056        0  [344, 466, 264, 379]            1       0
# 202173  100980        0  [321, 476, 297, 340]            1       0
#
#        segmentation  id  image_id
# 0                []   1         1
# 1                []   1         1
# 2                []   1         1
# ...

# %%
df_ann_41to50 = to_dataframe(path)
df_ann_41to50
# Out:
#          area  iscrowd                  bbox  category_id  ignore
# 0       40397        0  [348, 484, 199, 203]            1       0  \
# 1       42009        0  [356, 474, 201, 209]            1       0
# 2       42224        0  [369, 471, 203, 208]            1       0
# 3       42016        0  [379, 472, 202, 208]            1       0
# 4       42427        0  [394, 479, 203, 209]            1       0
# ...       ...      ...                   ...          ...     ...
# 183379  31320        0  [405, 545, 180, 174]            1       0
# 183380  31140        0  [408, 547, 180, 173]            1       0
# 183381  30780        0  [410, 554, 180, 171]            1       0
# 183382  31320        0  [411, 555, 180, 174]            1       0
# 183383  31675        0  [407, 560, 181, 175]            1       0
#
#        segmentation  id  image_id
# 0                []   1         1
# 1                []   1         1
# 2                []   1         1
# ...

# %%
df_ann_51to60 = to_dataframe(path)
df_ann_51to60
# Out:
#          area  iscrowd                  bbox  category_id  ignore
# 0       31862        0  [402, 539, 179, 178]            1       0  \
# 1       32220        0  [404, 545, 179, 180]            1       0
# 2       32220        0  [398, 548, 179, 180]            1       0
# 3       31862        0  [394, 553, 178, 179]            1       0
# 4       32400        0  [387, 550, 180, 180]            1       0
# ...       ...      ...                   ...          ...     ...
# 189643  35904        0  [436, 512, 176, 204]            1       0
# 189644  38600        0  [435, 529, 193, 200]            1       0
# 189645  37440        0  [427, 555, 208, 180]            1       0
# 189646  36081        0  [424, 575, 211, 171]            1       0
# 189647  35870        0  [415, 587, 211, 170]            1       0
#
#        segmentation  id  image_id
# 0                []   1         1
# 1                []   1         1
# 2                []   1         1
# ...

# %%
df_ann_61to70 = to_dataframe(path)
df_ann_61to70
# Out:
#          area  iscrowd                  bbox  category_id  ignore
# 0       36839        0  [356, 462, 197, 187]            1       0  \
# 1       36260        0  [375, 459, 196, 185]            1       0
# 2       36084        0  [398, 463, 194, 186]            1       0
# 3       34776        0  [416, 473, 189, 184]            1       0
# 4       35343        0  [430, 487, 189, 187]            1       0
# ...       ...      ...                   ...          ...     ...
# 178087  67620        0  [433, 515, 210, 322]            1       0
# 178088  79884        0  [399, 529, 252, 317]            1       0
# 178089  84360        0  [364, 543, 285, 296]            1       0
# 178090  83524        0  [330, 555, 314, 266]            1       0
# 178091  76461        0  [304, 563, 331, 231]            1       0
#
#        segmentation  id  image_id
# 0                []   1         1
# 1                []   1         1
# 2                []   1         1
# ...

# %%
df_ann_71to81 = to_dataframe(path)
df_ann_71to81
# Out:
#          area  iscrowd                  bbox  category_id  ignore
# 0       35908        0  [340, 509, 188, 191]            1       0  \
# 1       35720        0  [347, 510, 190, 188]            1       0
# 2       36670        0  [349, 503, 193, 190]            1       0
# 3       35530        0  [357, 506, 190, 187]            1       0
# 4       35720        0  [363, 503, 188, 190]            1       0
# ...       ...      ...                   ...          ...     ...
# 176790  33660        0  [395, 546, 187, 180]            1       0
# 176791  33480        0  [395, 547, 186, 180]            1       0
# 176792  31313        0  [396, 556, 181, 173]            1       0
# 176793  29392        0  [405, 554, 176, 167]            1       0
# 176794  31494        0  [405, 554, 181, 174]            1       0
#
#        segmentation  id  image_id
# 0                []   1         1
# 1                []   1         1
# 2                []   1         1
# ...

# %% [markdown]
# ## Data frame merge

# %%
df_ann = pd.concat([df_ann_1to5, df_ann_6to10, df_ann_11to15, df_ann_16to20, df_ann_21to25, df_ann_26to30,
                    df_ann_31to40, df_ann_41to50, df_ann_51to60, df_ann_61to70, df_ann_71to81], ignore_index = True)
df_ann
# Out:
#           area  iscrowd                  bbox  category_id  ignore
# 0        79508        0  [375, 474, 286, 278]            1       0  \
# 1        78668        0  [382, 482, 284, 277]            1       0
# 2        79242        0  [386, 491, 281, 282]            1       0
# 3        79524        0  [385, 502, 282, 282]            1       0
# 4        79520        0  [378, 512, 284, 280]            1       0
# ...        ...      ...                   ...          ...     ...
# 2451922  33660        0  [395, 546, 187, 180]            1       0
# 2451923  33480        0  [395, 547, 186, 180]            1       0
# 2451924  31313        0  [396, 556, 181, 173]            1       0
# 2451925  29392        0  [405, 554, 176, 167]            1       0
# 2451926  31494        0  [405, 554, 181, 174]            1       0
#
#         segmentation  id  image_id
# 0                 []   1         1
# 1                 []   1         1
# 2                 []   1         1
# ...

# %%
df_ann.to_csv('df_ann_json.csv')  # 저장

# %% [markdown]
# # images, annotations 병합

# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'c:\\dev\\github\\final\\collaborative\\final_project\\.github\\ISSUE_TEMPLATE'

# %%
# %cd C:/dev/github/final/Final_project/data
# Out:
# C:\dev\github\final\Final_project\data

# %%
df_img_json = pd.read_csv('df_img_json.csv', encoding = 'UTF-8')
df_img_json
# Out:
# C:\Users\유준선\AppData\Local\Temp\ipykernel_11304\3589493888.py:1: DtypeWarning: Columns (25,29,30,34,38,40,41,42,45,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_img_json = pd.read_csv('df_img_json.csv', encoding = 'UTF-8')
#          Unnamed: 0.1  Unnamed: 0                        file_name  width
# 0                   0           0  K-000059_0_0_0_0_60_000_200.png    976  \
# 1                   1           1  K-000059_0_0_0_0_60_020_200.png    976
# 2                   2           2  K-000059_0_0_0_0_60_040_200.png    976
# 3                   3           3  K-000059_0_0_0_0_60_060_200.png    976
# 4                   4           4  K-000059_0_0_0_0_60_080_200.png    976
# ...               ...         ...                              ...    ...
# 2451922       2451922      354882  K-039147_0_2_1_2_90_260_200.png    976
# 2451923       2451923      354883  K-039147_0_2_1_2_90_280_200.png    976
# ...

# %%
df_ann_json = pd.read_csv('df_ann_json.csv', encoding = 'UTF-8')
df_ann_json
# Out:
#          Unnamed: 0   area  iscrowd                  bbox  category_id
# 0                 0  79508        0  [375, 474, 286, 278]            1  \
# 1                 1  78668        0  [382, 482, 284, 277]            1
# 2                 2  79242        0  [386, 491, 281, 282]            1
# 3                 3  79524        0  [385, 502, 282, 282]            1
# 4                 4  79520        0  [378, 512, 284, 280]            1
# ...             ...    ...      ...                   ...          ...
# 2451922     2451922  33660        0  [395, 546, 187, 180]            1
# 2451923     2451923  33480        0  [395, 547, 186, 180]            1
# 2451924     2451924  31313        0  [396, 556, 181, 173]            1
# 2451925     2451925  29392        0  [405, 554, 176, 167]            1
# 2451926     2451926  31494        0  [405, 554, 181, 174]            1
#
#          ignore segmentation  id  image_id
# 0             0           []   1         1
# ...

# %%
df_img_json.shape, df_ann_json.shape
# Out:
# ((2451927, 52), (2451927, 9))

# %%
df_img_json.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'file_name', 'width', 'height', 'imgfile',
#        'drug_N', 'drug_S', 'back_color', 'drug_dir', 'light_color',
#        'camera_la', 'camera_lo', 'size', 'item_seq', 'leng_long', 'leng_short',
#        'thick', 'id', 'dl_idx', 'dl_mapping_code', 'dl_name', 'dl_name_en',
#        'img_key', 'dl_material', 'dl_material_en', 'dl_custom_shape',
#        'dl_company', 'dl_company_en', 'di_company_mf', 'di_company_mf_en',
#        'di_item_permit_date', 'di_class_no', 'di_etc_otc_code', 'di_edi_code',
#        'chart', 'drug_shape', 'print_front', 'print_back', 'color_class1',
#        'color_class2', 'line_front', 'line_back', 'img_regist_ts',
#        'form_code_name', 'mark_code_front_anal', 'mark_code_back_anal',
#        'mark_code_front_img', 'mark_code_back_img', 'mark_code_front',
#        'mark_code_back', 'change_date'],
#       dtype='object')

# %%
df_ann_json.columns
# Out:
# Index(['Unnamed: 0', 'area', 'iscrowd', 'bbox', 'category_id', 'ignore',
#        'segmentation', 'id', 'image_id'],
#       dtype='object')

# %% [markdown]
# ## 불필요한 index열 제거

# %%
df_img_json.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis = 1, inplace = True)
df_img_json
# Out:
#                                file_name  width  height
# 0        K-000059_0_0_0_0_60_000_200.png    976    1280  \
# 1        K-000059_0_0_0_0_60_020_200.png    976    1280
# 2        K-000059_0_0_0_0_60_040_200.png    976    1280
# 3        K-000059_0_0_0_0_60_060_200.png    976    1280
# 4        K-000059_0_0_0_0_60_080_200.png    976    1280
# ...                                  ...    ...     ...
# 2451922  K-039147_0_2_1_2_90_260_200.png    976    1280
# 2451923  K-039147_0_2_1_2_90_280_200.png    976    1280
# 2451924  K-039147_0_2_1_2_90_300_200.png    976    1280
# 2451925  K-039147_0_2_1_2_90_320_200.png    976    1280
# 2451926  K-039147_0_2_1_2_90_340_200.png    976    1280
#
#                                  imgfile    drug_N drug_S back_color drug_dir
# 0        K-000059_0_0_0_0_60_000_200.png  K-000059   정상알약     검은색 배경       앞면  \
# 1        K-000059_0_0_0_0_60_020_200.png  K-000059   정상알약     검은색 배경       앞면
# ...

# %%
df_ann_json.drop(['Unnamed: 0'], axis = 1, inplace = True)
df_ann_json
# Out:
#           area  iscrowd                  bbox  category_id  ignore
# 0        79508        0  [375, 474, 286, 278]            1       0  \
# 1        78668        0  [382, 482, 284, 277]            1       0
# 2        79242        0  [386, 491, 281, 282]            1       0
# 3        79524        0  [385, 502, 282, 282]            1       0
# 4        79520        0  [378, 512, 284, 280]            1       0
# ...        ...      ...                   ...          ...     ...
# 2451922  33660        0  [395, 546, 187, 180]            1       0
# 2451923  33480        0  [395, 547, 186, 180]            1       0
# 2451924  31313        0  [396, 556, 181, 173]            1       0
# 2451925  29392        0  [405, 554, 176, 167]            1       0
# 2451926  31494        0  [405, 554, 181, 174]            1       0
#
#         segmentation  id  image_id
# 0                 []   1         1
# 1                 []   1         1
# 2                 []   1         1
# ...

# %%
df_ann_json.drop(['iscrowd', 'category_id', 'ignore', 'segmentation', 'id', 'image_id'], axis = 1, inplace = True)
df_ann_json
# Out:
#           area                  bbox
# 0        79508  [375, 474, 286, 278]
# 1        78668  [382, 482, 284, 277]
# 2        79242  [386, 491, 281, 282]
# 3        79524  [385, 502, 282, 282]
# 4        79520  [378, 512, 284, 280]
# ...        ...                   ...
# 2451922  33660  [395, 546, 187, 180]
# 2451923  33480  [395, 547, 186, 180]
# 2451924  31313  [396, 556, 181, 173]
# 2451925  29392  [405, 554, 176, 167]
# 2451926  31494  [405, 554, 181, 174]
#
# [2451927 rows x 2 columns]

# %% [markdown]
# ## 최종 병합

# %%
df_json = pd.concat([df_img_json, df_ann_json], axis = 1)
df_json
# Out:
#                                file_name  width  height
# 0        K-000059_0_0_0_0_60_000_200.png    976    1280  \
# 1        K-000059_0_0_0_0_60_020_200.png    976    1280
# 2        K-000059_0_0_0_0_60_040_200.png    976    1280
# 3        K-000059_0_0_0_0_60_060_200.png    976    1280
# 4        K-000059_0_0_0_0_60_080_200.png    976    1280
# ...                                  ...    ...     ...
# 2451922  K-039147_0_2_1_2_90_260_200.png    976    1280
# 2451923  K-039147_0_2_1_2_90_280_200.png    976    1280
# 2451924  K-039147_0_2_1_2_90_300_200.png    976    1280
# 2451925  K-039147_0_2_1_2_90_320_200.png    976    1280
# 2451926  K-039147_0_2_1_2_90_340_200.png    976    1280
#
#                                  imgfile    drug_N drug_S back_color drug_dir
# 0        K-000059_0_0_0_0_60_000_200.png  K-000059   정상알약     검은색 배경       앞면  \
# 1        K-000059_0_0_0_0_60_020_200.png  K-000059   정상알약     검은색 배경       앞면
# ...

# %%
df_json.shape
# Out:
# (2451927, 52)

# %%
df_json.to_csv('df_json.csv')

# %% [markdown]
# # 전체파일 압축 풀기

# %%
# 최초 1번만 실행

# %%
import zipfile

# %%
# %pwd
# Out:
# 'c:\\dev\\github\\final\\collaborative\\final_project\\.github\\ISSUE_TEMPLATE'

# %%
path = pathlib.Path('C:/dev/github/final/Final_project/data')

# %%
def unzip(path):
    path_list = path.rglob('*.zip')
    for paths in (path_list):
        with zipfile.ZipFile(paths, 'r') as zip_ref:
            zip_ref.extractall(str(paths)[:-4])

# %%
unzip(path)
